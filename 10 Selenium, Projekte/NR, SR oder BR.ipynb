# %%
from bs4 import BeautifulSoup # liest Informationen aus
import requests
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
#Wir starten den Browser:
driver = webdriver.Chrome('/usr/local/bin/chromedriver')
#Wir besuchen die Site
driver.get("https://www.berufsberatung.ch/dyn/show/2930")

# %%
pd.read_csv("schweizerräte.csv")
df = pd.read_csv("schweizerräte.csv")
df_politiker = df["Name"]
df_politiker.head(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-cf77c974ac31> in <module>()
#       1 pd.read_csv("schweizerräte.csv")
# ...

# %%
df = pd.read_csv("schweizerräte.csv")

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Councillors    object
# dtype: object

# %%
df.shape
# Out:
# (246, 2)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Councillors    object
# dtype: object

# %%
df.head(10)
# Out:
#    Unnamed: 0               Councillors
# 0           0  Fabio Abate FDP-Liberale
# 1           1        Jean-Luc Addor SVP
# 2           2          Andreas Aebi SVP
# 3           3     Matthias Aebischer SP
# 4           4         Thomas Aeschi SVP
# 5           5           Evi Allemann SP
# 6           6       Céline Amaudruz SVP
# 7           7          Viola Amherd CVP
# 8           8         Thomas Ammann CVP
# 9           9        Adrian Amstutz SVP

# %%
df['Councillors'].unique()
# Out:
# array(['Fabio Abate FDP-Liberale', 'Jean-Luc Addor SVP',
#        'Andreas Aebi SVP', 'Matthias Aebischer SP', 'Thomas Aeschi SVP',
#        'Evi Allemann SP', 'Céline Amaudruz SVP', 'Viola Amherd CVP',
#        'Thomas Ammann CVP', 'Adrian Amstutz SVP', 'Beat Arnold SVP',
#        'Sibel Arslan BastA', 'Jacqueline Badran SP',
#        'Guillaume Barazzone CVP', 'Angelo Barrile SP',
#        'Philippe Bauer FDP-Liberale', 'Isidor Baumann CVP',
#        'Martin Bäumle glp', 'Claude Béglé CVP', 'Samuel Bendahan SP',
#        'Didier Berberat SP', 'Kathrin Bertschy glp',
#        'Hans-Ulrich Bigler FDP-Liberale', 'Prisca Birrer-Heimo SP',
#        'Pirmin Bischof CVP', 'Ivo Bischofberger CVP',
#        'Frédéric Borloz FDP-Liberale', 'Jacques Bourgeois FDP-Liberale',
#        'Heinz Brand SVP', 'Daniel Brélaz GPS', 'Pascale Bruderer Wyss SP',
#        'Hansjörg Brunner FDP-Liberale', 'Toni Brunner SVP',
#        'Roland Rino Büchel SVP', 'Michaël Buffat SVP',
# ...

# %%
df
# Out:
#      Unnamed: 0                          Councillors
# 0             0             Fabio Abate FDP-Liberale
# 1             1                   Jean-Luc Addor SVP
# 2             2                     Andreas Aebi SVP
# 3             3                Matthias Aebischer SP
# 4             4                    Thomas Aeschi SVP
# 5             5                      Evi Allemann SP
# 6             6                  Céline Amaudruz SVP
# 7             7                     Viola Amherd CVP
# 8             8                    Thomas Ammann CVP
# 9             9                   Adrian Amstutz SVP
# 10           10                      Beat Arnold SVP
# 11           11                   Sibel Arslan BastA
# 12           12                 Jacqueline Badran SP
# 13           13              Guillaume Barazzone CVP
# 14           14                    Angelo Barrile SP
# 15           15          Philippe Bauer FDP-Liberale
# 16           16                   Isidor Baumann CVP
# ...
