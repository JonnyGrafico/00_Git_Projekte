# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Leerflaechen-nach-Nutzungsart-und-Quartier.xlsx', header=8).fillna(0)

# %%
#  na_values=' '
    
#     df.set_index('New Date', inplace=True)

# %%
# df.fillna(0).head()

# %%
df.head()
# Out:
#                        Total  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# NaN          Leerfläche (m²)         0.0         0.0         0.0         0.0
# NaN                     2018      2017.0      2016.0      2015.0      2014.0
# Ganze Stadt           187714    243660.0    237054.0    256450.0    264548.0
# Kreis 1                30550     34710.0     32201.0     40945.0     53774.0
# Rathaus                 3504      1940.0      2261.0      2261.0      2284.0
#
#                  Büro/Praxis  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# NaN          Leerfläche (m²)         0.0         0.0         0.0         0.0
# NaN                     2018      2017.0      2016.0      2015.0      2014.0
# Ganze Stadt           139664    174381.0    193027.0    207901.0    214900.0
# Kreis 1                23805     29535.0     29807.0     36180.0     49692.0
# Rathaus                 1399      1940.0      1315.0      2113.0      1856.0
#
# ...

# %%
list1 = list(df)

# %%
list1
# Out:
# ['Total',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Büro/Praxis',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Lager/\nArchiv',
#  'Verkauf',
#  'Werkstatt/\nProduktion',
#  'Andere Nutzungen']

# %%
df = pd.read_excel('Leerflaechen-nach-Nutzungsart-und-Quartier.xlsx', header=9).fillna(0)

# %%
list2 = list(df)

# %%
list2
# Out:
# ['Leerfläche (m²)',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Leerfläche (m²).1',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Leerflächenziffer',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Leerfläche (m²).2',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18']

# %%
list3= []
for elem1, elem2 in zip(list1, list2):
    elem = elem1 + " "+elem2
    list3.append(elem)

# %%
list3
# Out:
# ['Total Leerfläche (m²)',
#  'Unnamed: 1 Unnamed: 1',
#  'Unnamed: 2 Unnamed: 2',
#  'Unnamed: 3 Unnamed: 3',
#  'Unnamed: 4 Unnamed: 4',
#  'Büro/Praxis Leerfläche (m²).1',
#  'Unnamed: 6 Unnamed: 6',
#  'Unnamed: 7 Unnamed: 7',
#  'Unnamed: 8 Unnamed: 8',
#  'Unnamed: 9 Unnamed: 9',
#  'Unnamed: 10 Leerflächenziffer',
#  'Unnamed: 11 Unnamed: 11',
#  'Unnamed: 12 Unnamed: 12',
#  'Unnamed: 13 Unnamed: 13',
#  'Unnamed: 14 Unnamed: 14',
#  'Lager/\nArchiv Leerfläche (m²).2',
#  'Verkauf Unnamed: 16',
#  'Werkstatt/\nProduktion Unnamed: 17',
#  'Andere Nutzungen Unnamed: 18']

# %%
df.columns = list3

# %%
df.columns
# Out:
# Index(['Total Leerfläche (m²)', 'Unnamed: 1 Unnamed: 1',
#        'Unnamed: 2 Unnamed: 2', 'Unnamed: 3 Unnamed: 3',
#        'Unnamed: 4 Unnamed: 4', 'Büro/Praxis Leerfläche (m²).1',
#        'Unnamed: 6 Unnamed: 6', 'Unnamed: 7 Unnamed: 7',
#        'Unnamed: 8 Unnamed: 8', 'Unnamed: 9 Unnamed: 9',
#        'Unnamed: 10 Leerflächenziffer', 'Unnamed: 11 Unnamed: 11',
#        'Unnamed: 12 Unnamed: 12', 'Unnamed: 13 Unnamed: 13',
#        'Unnamed: 14 Unnamed: 14', 'Lager/\nArchiv Leerfläche (m²).2',
#        'Verkauf Unnamed: 16', 'Werkstatt/\nProduktion Unnamed: 17',
#        'Andere Nutzungen Unnamed: 18'],
#       dtype='object')

# %%
df.columns
# Out:
#                       Total Leerfläche (m²)  Unnamed: 1 Unnamed: 1  \
# NaN                                    2018                   2017
# Ganze Stadt                          187714                 243660
# Kreis 1                               30550                  34710
# Rathaus                                3504                   1940
# Hochschulen                             670                   1187
# Lindenhof                              7542                  10304
# City                                  18834                  21279
# Kreis 2                               23200                  25173
# Wollishofen                            2220                   4227
# Leimbach                                  0                      0
# Enge                                  20980                  20946
# Kreis 3                               19407                  20063
# Alt-Wiedikon                          16268                  16327
# ...

# %%
df_auswahl = df[['Total Leerfläche (m²)', 'Unnamed: 1 Unnamed: 1']]



# df_ohnere_total = df[['Industrie - Total', 'Dienste - Total', 'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        #'Pro memoria: Grundstücks- und Wohnungswesen',
#        #'Pro memoria: Total inkl. Grundstücks- und Wohnungswesen'
#         ]]

# %%
df_auswahl[0:].reset_index()
# Out:
#                    index  Total Leerfläche (m²)  Unnamed: 1 Unnamed: 1
# 0                    NaN                   2018                   2017
# 1            Ganze Stadt                 187714                 243660
# 2                Kreis 1                  30550                  34710
# 3                Rathaus                   3504                   1940
# 4            Hochschulen                    670                   1187
# 5              Lindenhof                   7542                  10304
# 6                   City                  18834                  21279
# 7                Kreis 2                  23200                  25173
# 8            Wollishofen                   2220                   4227
# 9               Leimbach                      0                      0
# 10                  Enge                  20980                  20946
# 11               Kreis 3                  19407                  20063
# ...

# %%
# df.transpose()

# %%
df.dtypes
# Out:
# Unnamed: 0 Leerfläche (m²)              int64
# Total Unnamed: 1                        int64
# Unnamed: 2 Unnamed: 2                   int64
# Unnamed: 3 Unnamed: 3                 float64
# Unnamed: 4 Unnamed: 4                   int64
# Unnamed: 5 Leerfläche (m²).1            int64
# Büro/Praxis Unnamed: 6                  int64
# Unnamed: 7 Unnamed: 7                   int64
# Unnamed: 8 Unnamed: 8                   int64
# Unnamed: 9 Unnamed: 9                   int64
# Unnamed: 10 Leerflächenziffer         float64
# Unnamed: 11 Unnamed: 11               float64
# Unnamed: 12 Unnamed: 12               float64
# Unnamed: 13 Unnamed: 13               float64
# Unnamed: 14 Unnamed: 14               float64
# Unnamed: 15 Leerfläche (m²).2           int64
# Lager/\nArchiv Unnamed: 16              int64
# Verkauf Unnamed: 17                     int64
# Werkstatt/\nProduktion Unnamed: 18      int64
# dtype: object

# %%
df = pd.read_excel('Leerflaechen-nach-Nutzungsart-und-Quartier.xlsx', header=10).fillna(0)

# %%
df.columns.astype(str)
# Out:
# Index(['2018', '2017', '2016', '2015', '2014', '2018.1', '2017.1', '2016.1',
#        '2015.1', '2014.1', '2018.2', '2017.2', '2016.2', '2015.2', '2014.2',
#        '2018.3', '2018.4', '2018.5', '2018.6'],
#       dtype='object')

# %%
list3 = list(df)

# %%
list3
# Out:
# [2018,
#  2017,
#  2016,
#  2015,
#  2014,
#  '2018.1',
#  '2017.1',
#  '2016.1',
#  '2015.1',
#  '2014.1',
#  '2018.2',
#  '2017.2',
#  '2016.2',
#  '2015.2',
#  '2014.2',
#  '2018.3',
#  '2018.4',
#  '2018.5',
#  '2018.6']

# %%
list4 = []
for elem1, elem2, elem3 in zip(list1, list2, list3):
    elem = elem1 + " "+elem2 + " "+elem3
    list4.append(elem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-98a26314a51f> in <module>
#       1 list4 = []
#       2 for elem1, elem2, elem3 in zip(list1, list2, list3):
# ----> 3     elem = elem1 + " "+elem2 + " "+elem3
#       4     list4.append(elem)
#
# TypeError: can only concatenate str (not "int") to str

# %%
list4
# Out:
# []

# %%
df.columns = list3

# %%
df[0:]
# Out:
#                         2018    2017    2016      2015    2014  2018.1  \
# Ganze Stadt           187714  243660  237054  256450.0  264548  139664
# Kreis 1                30550   34710   32201   40945.0   53774   23805
# Rathaus                 3504    1940    2261    2261.0    2284    1399
# Hochschulen              670    1187     340     126.0    2218     670
# Lindenhof               7542   10304    8060    7737.0    7381    6963
# City                   18834   21279   21540   30821.0   41891   14773
# Kreis 2                23200   25173   19439   30347.0   34236   19520
# Wollishofen             2220    4227    5313    3790.0    9101    1741
# Leimbach                   0       0       0       0.0     401       0
# Enge                   20980   20946   14126   26557.0   24734   17779
# Kreis 3                19407   20063   22593   38728.0   34681   11823
# Alt-Wiedikon           16268   16327   19741   33457.0   26935   10489
# ...

# %%
df.transpose()
# Out:
#           Ganze Stadt       Kreis 1      Rathaus  Hochschulen     Lindenhof  \
# 2018    187714.000000  30550.000000  3504.000000   670.000000   7542.000000
# 2017    243660.000000  34710.000000  1940.000000  1187.000000  10304.000000
# 2016    237054.000000  32201.000000  2261.000000   340.000000   8060.000000
# 2015    256450.000000  40945.000000  2261.000000   126.000000   7737.000000
# 2014    264548.000000  53774.000000  2284.000000  2218.000000   7381.000000
# 2018.1  139664.000000  23805.000000  1399.000000   670.000000   6963.000000
# 2017.1  174381.000000  29535.000000  1940.000000   797.000000   8158.000000
# 2016.1  193027.000000  29807.000000  1315.000000   340.000000   7725.000000
# 2015.1  207901.000000  36180.000000  2113.000000   126.000000   7374.000000
# 2014.1  214900.000000  49692.000000  1856.000000  2218.000000   6967.000000
# 2018.2       1.820000      3.009313     1.312454     0.870212      3.940022
# ...

# %%
df2 = pd.read_excel('Leerflaechen-nach-Nutzungsart-und-Quartier.xlsx', header=9).fillna(0)

# %%
df2
# Out:
#                       Leerfläche (m²)  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# NaN                              2018        2017        2016      2015.0
# Ganze Stadt                    187714      243660      237054    256450.0
# Kreis 1                         30550       34710       32201     40945.0
# Rathaus                          3504        1940        2261      2261.0
# Hochschulen                       670        1187         340       126.0
# Lindenhof                        7542       10304        8060      7737.0
# City                            18834       21279       21540     30821.0
# Kreis 2                         23200       25173       19439     30347.0
# Wollishofen                      2220        4227        5313      3790.0
# Leimbach                            0           0           0         0.0
# Enge                            20980       20946       14126     26557.0
# Kreis 3                         19407       20063       22593     38728.0
# ...

# %%
df2.dtypes
# Out:
# Leerfläche (m²)        int64
# Unnamed: 1             int64
# Unnamed: 2             int64
# Unnamed: 3           float64
# Unnamed: 4             int64
# Leerfläche (m²).1      int64
# Unnamed: 6             int64
# Unnamed: 7             int64
# Unnamed: 8             int64
# Unnamed: 9             int64
# Leerflächenziffer    float64
# Unnamed: 11          float64
# Unnamed: 12          float64
# Unnamed: 13          float64
# Unnamed: 14          float64
# Leerfläche (m²).2      int64
# Unnamed: 16            int64
# Unnamed: 17            int64
# Unnamed: 18            int64
# dtype: object

# %%
df2 = df.astype(str)

# %%
# df_list2 = list(df)

# %%
df2.dtypes
# Out:
# 2018      object
# 2017      object
# 2016      object
# 2015      object
# 2014      object
# 2018.1    object
# 2017.1    object
# 2016.1    object
# 2015.1    object
# 2014.1    object
# 2018.2    object
# 2017.2    object
# 2016.2    object
# 2015.2    object
# 2014.2    object
# 2018.3    object
# 2018.4    object
# 2018.5    object
# 2018.6    object
# dtype: object

# %%
df.columns
# Out:
# Index([    2018,     2017,     2016,     2015,     2014, '2018.1', '2017.1',
#        '2016.1', '2015.1', '2014.1', '2018.2', '2017.2', '2016.2', '2015.2',
#        '2014.2', '2018.3', '2018.4', '2018.5', '2018.6'],
#       dtype='object')

# %%
df_ohnere_total = df[['Unnamed: 5', 'Unnamed: 7']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-819aad6aa7fb> in <module>
# ----> 1 df_ohnere_total = df[['Unnamed: 5', 'Unnamed: 7']]
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
df_ohnere_total
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2d650f832d29> in <module>
# ----> 1 df_ohnere_total
#
# NameError: name 'df_ohnere_total' is not defined

# %%
# df2[['Unnamed: 3'], ['Leerflächenziffer']].astype(str)
df2
# Out:
#                         2018    2017    2016      2015    2014  2018.1  \
# Ganze Stadt           187714  243660  237054  256450.0  264548  139664
# Kreis 1                30550   34710   32201   40945.0   53774   23805
# Rathaus                 3504    1940    2261    2261.0    2284    1399
# Hochschulen              670    1187     340     126.0    2218     670
# Lindenhof               7542   10304    8060    7737.0    7381    6963
# City                   18834   21279   21540   30821.0   41891   14773
# Kreis 2                23200   25173   19439   30347.0   34236   19520
# Wollishofen             2220    4227    5313    3790.0    9101    1741
# Leimbach                   0       0       0       0.0     401       0
# Enge                   20980   20946   14126   26557.0   24734   17779
# Kreis 3                19407   20063   22593   38728.0   34681   11823
# Alt-Wiedikon           16268   16327   19741   33457.0   26935   10489
# ...

# %%
df.column['Leerflächenziffer']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-6b205e95c076> in <module>
# ----> 1 df.column['Leerflächenziffer']
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df2.transpose()
# Out:
#                Ganze Stadt             Kreis 1             Rathaus  \
# 2018                187714               30550                3504
# 2017                243660               34710                1940
# 2016                237054               32201                2261
# 2015              256450.0             40945.0              2261.0
# 2014                264548               53774                2284
# 2018.1              139664               23805                1399
# 2017.1              174381               29535                1940
# 2016.1              193027               29807                1315
# 2015.1              207901               36180                2113
# 2014.1              214900               49692                1856
# 2018.2                1.82  3.0093125714045508  1.3124536706153467
# 2017.2   2.294605920446295  3.7223810104713992  1.8283085995548578
# 2016.2   2.550520274842115   3.713889320199774   1.280150924682259
# ...

# %%
df_list2.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-247-3d170054fe04> in <module>
# ----> 1 df_list2.types
#
# AttributeError: 'list' object has no attribute 'types'

# %%
list3 = []
for elem1, elem2 in zip(list1, list2):
    elem = elem1 + " "+elem2
    list3.append(elem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-228-3646118d1c17> in <module>
#       1 list3 = []
#       2 for elem1, elem2 in zip(list1, list2):
# ----> 3     elem = elem1 + " "+elem2
#       4     list3.append(elem)
#
# TypeError: can only concatenate str (not "int") to str

# %%
list2 = df_transposed2[1:]

# %%
list2.iloc[2:6, 1:6]
# Out:
#               NaN Ganze Stadt Kreis 1 Rathaus Hochschulen
# Unnamed: 3   2015      256450   40945    2261         126
# Unnamed: 4   2014      264548   53774    2284        2218
# Büro/Praxis  2018      139664   23805    1399         670
# Unnamed: 6   2017      174381   29535    1940         797

# %%
# list2.iloc[2:6, 1:6]

# %%
df = pd.read_excel('Leerflaechen-nach-Nutzungsart-und-Quartier.xlsx', header=10)

# %%
df.transpose()
# Out:
#           Ganze Stadt       Kreis 1      Rathaus  Hochschulen     Lindenhof  \
# 2018    187714.000000  30550.000000  3504.000000   670.000000   7542.000000
# 2017    243660.000000  34710.000000  1940.000000  1187.000000  10304.000000
# 2016    237054.000000  32201.000000  2261.000000   340.000000   8060.000000
# 2015    256450.000000  40945.000000  2261.000000   126.000000   7737.000000
# 2014    264548.000000  53774.000000  2284.000000  2218.000000   7381.000000
# 2018.1  139664.000000  23805.000000  1399.000000   670.000000   6963.000000
# 2017.1  174381.000000  29535.000000  1940.000000   797.000000   8158.000000
# 2016.1  193027.000000  29807.000000  1315.000000   340.000000   7725.000000
# 2015.1  207901.000000  36180.000000  2113.000000   126.000000   7374.000000
# 2014.1  214900.000000  49692.000000  1856.000000  2218.000000   6967.000000
# 2018.2       1.820000      3.009313     1.312454     0.870212      3.940022
# ...

# %%
# df[Jahre].astype(str).astype('int64')


df['2018.1'] = df.2018.1.astype(float)
# Out:
#   File "<ipython-input-57-6569b42b0ead>", line 4
#     df['2018.1'] = df.2018.1.astype(float)
#                          ^
# SyntaxError: invalid syntax

# %%
df.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-3c024b1b554d> in <module>
# ----> 1 df.types
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
list2 = list(df)
list2





# >>> df['purchase'].astype(str).astype(int)
# Out:
# [2018,
#  2017,
#  2016,
#  2015,
#  2014,
#  '2018.1',
#  '2017.1',
#  '2016.1',
#  '2015.1',
#  '2014.1',
#  '2018.2',
#  '2017.2',
#  '2016.2',
#  '2015.2',
#  '2014.2',
#  '2018.3',
#  '2018.4',
#  '2018.5',
#  '2018.6']

# %%
Jahre = list2

# %%
# df[Jahre].astype(str).astype('int64')


Jahre['2018.1'] = Jahre.astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-f8d9f97efe98> in <module>
#       2
#       3
# ----> 4 Jahre['2018.1'] = Jahre.astype(float)
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
df.dtypes
# Out:
# 2018        int64
# 2017        int64
# 2016        int64
# 2015      float64
# 2014        int64
# 2018.1      int64
# 2017.1      int64
# 2016.1      int64
# 2015.1      int64
# 2014.1      int64
# 2018.2    float64
# 2017.2    float64
# 2016.2    float64
# 2015.2    float64
# 2014.2    float64
# 2018.3      int64
# 2018.4      int64
# 2018.5      int64
# 2018.6      int64
# dtype: object

# %%
df.dtypes
# Out:
# 2018        int64
# 2017        int64
# 2016        int64
# 2015      float64
# 2014        int64
# 2018.1      int64
# 2017.1      int64
# 2016.1      int64
# 2015.1      int64
# 2014.1      int64
# 2018.2    float64
# 2017.2    float64
# 2016.2    float64
# 2015.2    float64
# 2014.2    float64
# 2018.3      int64
# 2018.4      int64
# 2018.5      int64
# 2018.6      int64
# dtype: object

# %%
df['Approved Amount'] = df['Approved Amount'].astype(float)

# %%
list3 = []
for elem1, elem2 in zip(list1, list2):
    elem = elem1 + " "+elem2
    list3.append(elem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-3646118d1c17> in <module>
#       1 list3 = []
#       2 for elem1, elem2 in zip(list1, list2):
# ----> 3     elem = elem1 + " "+elem2
#       4     list3.append(elem)
#
# TypeError: can only concatenate str (not "int") to str
