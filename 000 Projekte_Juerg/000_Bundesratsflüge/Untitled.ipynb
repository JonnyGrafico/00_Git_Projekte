# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('2015_Bundesrat.xlsx', index_col=0, header=0)
# df = pd.read_excel('000_snb-di_ohne_reinvestierte.xlsx')

# %%
df.fillna(0)
# Out:
#                         Unnamed: 1     Departement             F900  \
# Name
# BR                             E11       Bundesrat                0
# Leer                          E11L  Leerflüge alle  18:35:00.038000
# Leer 2                        E11P   Leerflüge Pos  12:02:00.010000
# Burkhalter Didier             E11A             EDA        180:13:00
# Widmer-Schlumpf Eveline       E11F             EFD         07:12:00
# Berset Alain                  E11I             EDI  06:36:59.962000
# Sommaruga Simonetta           E11J            EJPD         50:15:00
# Leuthard Doris                E11U      UVEK, E11U         27:33:00
# Maurer Ueli                   E11V             VBS         38:47:00
# Schneider-Ammann Johann       E11W             WBF         60:39:00
# NaN                          TOTAL       Bundesrat                0
#
#                                       BD               XL               SK  \
# Name
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'Departement', 'F900', 'BD', 'XL', 'SK', 'eingemietet',
#        'Total Flugzeuge', 'Unnamed: 9', 'E6', 'SP', 'SC', 'Total Helikopter',
#        'BR / Dep.'],
#       dtype='object')

# %%
df.shape
# Out:
# (11, 14)

# %%
df_ohnere_total = df[['Total Flugzeuge',
       'Total Helikopter']]

df_ohnere_total.iloc[3:10]
#.plot(
#     kind='bar', figsize=(15,10),
#     fontsize=14,
#     title="DI: Beteiligungskapital ohne reinvestierte Erträge – Total")
# Out:
#                         Total Flugzeuge Total Helikopter
# Name
# Burkhalter Didier             200:28:00         20:42:00
# Widmer-Schlumpf Eveline        10:57:00  03:13:59.981000
# Berset Alain                   14:15:00         40:42:00
# Sommaruga Simonetta            76:25:00         24:50:00
# Leuthard Doris                 35:09:00  13:54:59.990000
# Maurer Ueli                    40:48:00  02:05:00.038000
# Schneider-Ammann Johann        68:12:00         75:15:00

# %%
# df_ohnere_total = df[['Industrie - Total', 'Dienste - Total', 'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        #'Pro memoria: Grundstücks- und Wohnungswesen',
#        #'Pro memoria: Total inkl. Grundstücks- und Wohnungswesen'
#         ]]
# df_ohnere_total.iloc[8:19].apply(lambda x: x/1000).plot(
#     kind='bar', figsize=(15,10),
#     fontsize=14,
#     title="DI: Beteiligungskapital ohne reinvestierte Erträge – Total")
