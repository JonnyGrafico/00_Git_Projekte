# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
#df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx')

# %%
df
# Out:
#     Jahre     Industrie  Industrie - Textilien und Bekleidung  \
# 0    1998   6374.000000                               285.500
# 1    1999   4606.000000                               440.000
# 2    2000  17634.500000                                19.000
# 3    2001   8012.800000                              -224.900
# 4    2002  11437.200000                                37.300
# 5    2003   2180.900000                               421.500
# 6    2004  11829.500000                               791.400
# 7    2005  10192.900000                              1430.300
# 8    2006  30913.100000                              1838.700
# 9    2007   9862.100000                              3592.000
# 10   2008  14370.800000                              1034.000
# 11   2009      8.200000                               -69.000
# 12   2010   1400.500000                             -3157.400
# 13   2011  -8520.400000                             -4491.200
# ...

# %%
df.set_index('Jahre')
df.fillna(0)
# Out:
#     Jahre     Industrie  Industrie - Textilien und Bekleidung  \
# 0    1998   6374.000000                               285.500
# 1    1999   4606.000000                               440.000
# 2    2000  17634.500000                                19.000
# 3    2001   8012.800000                              -224.900
# 4    2002  11437.200000                                37.300
# 5    2003   2180.900000                               421.500
# 6    2004  11829.500000                               791.400
# 7    2005  10192.900000                              1430.300
# 8    2006  30913.100000                              1838.700
# 9    2007   9862.100000                              3592.000
# 10   2008  14370.800000                              1034.000
# 11   2009      8.200000                               -69.000
# 12   2010   1400.500000                             -3157.400
# 13   2011  -8520.400000                             -4491.200
# ...

# %%
df[['Industrie', 'Dienste']].head(5)
# Out:
#    Industrie  Dienste
# 0     6374.0  10574.8
# 1     4606.0  19229.1
# 2    17634.5  38377.8
# 3     8012.8  13982.6
# 4    11437.2  13146.4

# %%
df['Industrie'] = df['Industrie'].apply(lambda x: x/1000)

# %%
df
# Out:
#     Jahre  Industrie  Industrie - Textilien und Bekleidung  \
# 0    1998   6.374000                               285.500
# 1    1999   4.606000                               440.000
# 2    2000  17.634500                                19.000
# 3    2001   8.012800                              -224.900
# 4    2002  11.437200                                37.300
# 5    2003   2.180900                               421.500
# 6    2004  11.829500                               791.400
# 7    2005  10.192900                              1430.300
# 8    2006  30.913100                              1838.700
# 9    2007   9.862100                              3592.000
# 10   2008  14.370800                              1034.000
# 11   2009   0.008200                               -69.000
# 12   2010   1.400500                             -3157.400
# 13   2011  -8.520400                             -4491.200
# 14   2012   9.014200                              1073.200
# ...

# %% [markdown]
# # Thierry, help!

# %% [markdown]
# Hier will ich die Millionen in Milliarden darstellen.
#
# Beispiel Industrie:
#
#     6374.0 Millionen = 6.374 Milliarden
#
#
# Wie kriege ich die Daten von Zeile [7] in der Grafik Zeile [10] in der y-Achse dargestellt?
#
# Nicht 30000 Millionen Franken sondern 30 Milliarden Franken
#
#
# Danke vielmal! :-))

# %%
#df_mrd

# %%
#Industrie_Sektionen = ['Jahre', 'df_mrd']

# %%
# Draw a graph with pandas and keep what's returned
ax = df.plot(kind='bar', x='Jahre',
             y=['Industrie'],
             figsize=(15,10), fontsize=14)

# Set the x scale because otherwise it goes into weird negative numbers
# ax.set_xlim((0, 70000))

# Set the x-axis label
ax.set_xlabel("Jahre", fontname="Arial", fontsize=14, fontweight='bold')

# Set the y-axis label
ax.set_ylabel("Milliarden Franken", fontsize=14)

# Set the y-axis titel
ax.set_title("Industrie Sektionen", fontname="Arial", fontsize=22)

ax.grid(b=None, which='major', axis='both', color='#DFEBEC', linestyle='--', linewidth=1)

ax.set_axisbelow(True)

# %%
df_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2d133f3be267> in <module>()
# ----> 1 df_
#
# NameError: name 'df_' is not defined

# %%
index = ['Jahre']

columns = ['Industrie','Dienste']

df_ = pd.DataFrame(index=index, columns=columns)
df_ = df_.fillna(0) # with 0s rather than NaNs

# %%
my_dict = ()
df = pd(my_dict, columns=["Industrie", "Dienste"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-419cacc909ca> in <module>()
#       1 my_dict = ()
# ----> 2 df = pd(my_dict, columns=["Industrie", "Dienste"])
#
# TypeError: 'module' object is not callable

# %%
nums = df['Industrie'], df['Dienste'] 
squares = []
for x in nums:
    squares.append(x / 1000)
print(squares)
# Out:
# [0      6.374000
# 1      4.606000
# 2     17.634500
# 3      8.012800
# 4     11.437200
# 5      2.180900
# 6     11.829500
# 7     10.192900
# 8     30.913100
# 9      9.862100
# 10    14.370800
# 11     0.008200
# 12     1.400500
# 13    -8.520400
# 14     9.014200
# 15    -3.108700
# 16    -6.511977
# 17     1.856291
# 18    20.677644
# Name: Industrie, dtype: float64, 0     10.574800
# 1     19.229100
# 2     38.377800
# 3     13.982600
# 4     13.146400
# 5      3.399600
# 6     -0.212800
# 7     11.789300
# 8     31.762700
# 9     36.614000
# 10    34.235500
# 11     8.347500
# 12    27.383900
# 13    12.726200
# 14    23.174300
# 15    11.597500
# 16   -27.645577
# 17    48.917793
# 18    -7.684544
# Name: Dienste, dtype: float64]

# %%
df_Industrie.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-de1b9bf50913> in <module>()
# ----> 1 df_Industrie.head(2)
#
# NameError: name 'df_Industrie' is not defined

# %%
df_Industrie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-fed790ee618f> in <module>()
# ----> 1 df_Industrie
#
# NameError: name 'df_Industrie' is not defined

# %%
nums = df['Industrie'], df['Dienste'] 
squares = []
for x in nums:
    squares.append(x / 1000)
print(squares)
# Out:
# [0      6.374000
# 1      4.606000
# 2     17.634500
# 3      8.012800
# 4     11.437200
# 5      2.180900
# 6     11.829500
# 7     10.192900
# 8     30.913100
# 9      9.862100
# 10    14.370800
# 11     0.008200
# 12     1.400500
# 13    -8.520400
# 14     9.014200
# 15    -3.108700
# 16    -6.511977
# 17     1.856291
# 18    20.677644
# Name: Industrie, dtype: float64, 0     10.574800
# 1     19.229100
# 2     38.377800
# 3     13.982600
# 4     13.146400
# 5      3.399600
# 6     -0.212800
# 7     11.789300
# 8     31.762700
# 9     36.614000
# 10    34.235500
# 11     8.347500
# 12    27.383900
# 13    12.726200
# 14    23.174300
# 15    11.597500
# 16   -27.645577
# 17    48.917793
# 18    -7.684544
# Name: Dienste, dtype: float64]

# %%
path = 'snb-data-fdiaustabsa-de-all-20171215_0900.xlsx'

# %%
df = pd.read_excel(path, na_values='-')

# %%
df
# Out:
#     Jahre     Industrie  Industrie - Textilien und Bekleidung  \
# 0    1998   6374.000000                               285.500
# 1    1999   4606.000000                               440.000
# 2    2000  17634.500000                                19.000
# 3    2001   8012.800000                              -224.900
# 4    2002  11437.200000                                37.300
# 5    2003   2180.900000                               421.500
# 6    2004  11829.500000                               791.400
# 7    2005  10192.900000                              1430.300
# 8    2006  30913.100000                              1838.700
# 9    2007   9862.100000                              3592.000
# 10   2008  14370.800000                              1034.000
# 11   2009      8.200000                               -69.000
# 12   2010   1400.500000                             -3157.400
# 13   2011  -8520.400000                             -4491.200
# ...

# %%
df.set_index('Jahre')
# Out:
#           Industrie  Industrie - Textilien und Bekleidung  \
# Jahre
# 1998    6374.000000                               285.500
# 1999    4606.000000                               440.000
# 2000   17634.500000                                19.000
# 2001    8012.800000                              -224.900
# 2002   11437.200000                                37.300
# 2003    2180.900000                               421.500
# 2004   11829.500000                               791.400
# 2005   10192.900000                              1430.300
# 2006   30913.100000                              1838.700
# 2007    9862.100000                              3592.000
# 2008   14370.800000                              1034.000
# 2009       8.200000                               -69.000
# 2010    1400.500000                             -3157.400
# 2011   -8520.400000                             -4491.200
# 2012    9014.200000                              1073.200
# ...

# %%
df.dtypes.head(5)
# Out:
# Jahre                                     int64
# Industrie                               float64
# Industrie - Textilien und Bekleidung    float64
# Industrie - Chemie und Kunststoffe      float64
# Industrie - Metalle und Maschinen       float64
# dtype: object

# %%
felderliste = ['Industrie', 'Dienste']

# %%
df[felderliste].head(5)
# Out:
#    Industrie  Dienste
# 0     6374.0  10574.8
# 1     4606.0  19229.1
# 2    17634.5  38377.8
# 3     8012.8  13982.6
# 4    11437.2  13146.4

# %%
series_list = pd.Series(['Industrie', 'Dienste'])

# %%
df[series_list].head(5)
# Out:
#    Industrie  Dienste
# 0     6374.0  10574.8
# 1     4606.0  19229.1
# 2    17634.5  38377.8
# 3     8012.8  13982.6
# 4    11437.2  13146.4

# %%
nums = df['Industrie'], df['Dienste'] 
squares = []
for x in nums:
    squares.append(x / 1000)
print(squares)
# Out:
# [0      6.374000
# 1      4.606000
# 2     17.634500
# 3      8.012800
# 4     11.437200
# 5      2.180900
# 6     11.829500
# 7     10.192900
# 8     30.913100
# 9      9.862100
# 10    14.370800
# 11     0.008200
# 12     1.400500
# 13    -8.520400
# 14     9.014200
# 15    -3.108700
# 16    -6.511977
# 17     1.856291
# 18    20.677644
# Name: Industrie, dtype: float64, 0     10.574800
# 1     19.229100
# 2     38.377800
# 3     13.982600
# 4     13.146400
# 5      3.399600
# 6     -0.212800
# 7     11.789300
# 8     31.762700
# 9     36.614000
# 10    34.235500
# 11     8.347500
# 12    27.383900
# 13    12.726200
# 14    23.174300
# 15    11.597500
# 16   -27.645577
# 17    48.917793
# 18    -7.684544
# Name: Dienste, dtype: float64]

# %%
df.head(5)
# Out:
#    Jahre  Industrie  Industrie - Textilien und Bekleidung  \
# 0   1998     6374.0                                 285.5
# 1   1999     4606.0                                 440.0
# 2   2000    17634.5                                  19.0
# 3   2001     8012.8                                -224.9
# 4   2002    11437.2                                  37.3
#
#    Industrie - Chemie und Kunststoffe  Industrie - Metalle und Maschinen  \
# 0                              3829.8                              819.5
# 1                               198.5                              650.8
# 2                              7680.3                             1271.6
# 3                              2583.7                             1707.4
# 4                              3444.0                              431.8
#
#    Industrie - Elektronik, Energie, Optik und Uhren  \
# 0                                             108.0
# 1                                            1111.1
# ...

# %%
#df.dtypes

# %%
#df['Jahre']

# %%
#df['Industrie - Total']

# %%
#df["Industrie"] = df['Industrie'].astype('int')
#df.dtypes

# %%
#df.Jahre.sort_index()

# %%
#df.Industrie.sort_index()

# %% [markdown]
# ## Industrie – Sektionen

# %% [markdown]
# dsfsdfsd

# %%
Industrie_Sektionen = ['Jahre', 'Industrie - Textilien und Bekleidung',
               'Industrie - Chemie und Kunststoffe', 'Industrie - Metalle und Maschinen',
               'Industrie - Elektronik, Energie, Optik und Uhren', 'Industrie - Übrige Industrien und Bau']

# %%
df[Industrie_Sektionen].head(5)
# Out:
#    Jahre  Industrie - Textilien und Bekleidung  \
# 0   1998                                 285.5
# 1   1999                                 440.0
# 2   2000                                  19.0
# 3   2001                                -224.9
# 4   2002                                  37.3
#
#    Industrie - Chemie und Kunststoffe  Industrie - Metalle und Maschinen  \
# 0                              3829.8                              819.5
# 1                               198.5                              650.8
# 2                              7680.3                             1271.6
# 3                              2583.7                             1707.4
# 4                              3444.0                              431.8
#
#    Industrie - Elektronik, Energie, Optik und Uhren  \
# 0                                             108.0
# 1                                            1111.1
# 2                                            2062.0
# ...

# %%
# Draw a graph with pandas and keep what's returned
ax = df.plot(kind='bar', x='Jahre',
             y=['Industrie - Textilien und Bekleidung',
             'Industrie - Chemie und Kunststoffe',
             'Industrie - Metalle und Maschinen',
             'Industrie - Elektronik, Energie, Optik und Uhren',
             'Industrie - Übrige Industrien und Bau'],
             figsize=(15,10), fontsize=14)

# Set the x scale because otherwise it goes into weird negative numbers
# ax.set_xlim((0, 70000))

# Set the x-axis label
ax.set_xlabel("Jahre", fontname="Arial", fontsize=14, fontweight='bold')

# Set the y-axis label
ax.set_ylabel("Millionen Franken", fontsize=14)

# Set the y-axis titel
ax.set_title("Industrie Sektionen", fontname="Arial", fontsize=22)

ax.grid(b=None, which='major', axis='both', color='#DFEBEC', linestyle='--', linewidth=1)

ax.set_axisbelow(True)

# %% [markdown]
# ## Dienste – Finanz- und Holdingsgesellschaften

# %% [markdown]
# sadasdasdasds

# %%
Dienste_Finanz_Holdings = ['Jahre', 'Dienste - Handel',
               'Dienste - Finanz- und Holdinggesellschaften - Total',
               'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
               'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3',
               'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities.3']

# %%
df[Dienste_Finanz_Holdings].head(5)
# Out:
#    Jahre  Dienste - Handel  \
# 0   1998             369.0
# 1   1999              52.8
# 2   2000             109.2
# 3   2001             890.9
# 4   2002             -90.2
#
#    Dienste - Finanz- und Holdinggesellschaften - Total  \
# 0                                              565.5
# 1                                             3778.3
# 2                                             1900.7
# 3                                              167.5
# 4                                             3710.7
#
#    Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht  \
# 0                                             1133.4
# 1                                              150.3
# 2                                             2002.9
# 3                                             1394.8
# 4                                             2345.2
#
#    Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3  \
# ...

# %%
# Draw a graph with pandas and keep what's returned
ax = df.plot(kind='bar', x='Jahre',
             y=['Dienste - Handel',
               'Dienste - Finanz- und Holdinggesellschaften - Total',
               'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
               'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3',
               'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities.3'],
             figsize=(15,10), fontsize=14)

# Set the x scale because otherwise it goes into weird negative numbers
# ax.set_xlim((0, 70000))

# Set the x-axis label
ax.set_xlabel("Jahre", fontname="Arial", fontsize=14, fontweight='bold')

# Set the y-axis label
ax.set_ylabel("Millionen Franken", fontsize=14)

# Set the y-axis titel
ax.set_title("Dienste – Finanz- und Holdingsgesellschaften", fontname="Arial", fontsize=22)

ax.grid(b=None, which='major', axis='both', color='#DFEBEC', linestyle='--', linewidth=1)

ax.set_axisbelow(True)

# %% [markdown]
# ## Dienste

# %% [markdown]
# asdasdasd

# %%
Dienste = ['Jahre',
           'Dienste - Banken.3',
           'Dienste - Versicherungen.3',
           'Dienste - Transporte und Kommunikation.3',
           'Dienste - Übrige Dienste.3']

# %%
df[Dienste].head(5)
# Out:
#    Jahre  Dienste - Banken.3  Dienste - Versicherungen.3  \
# 0   1998              -321.2                      8034.4
# 1   1999              6082.0                      9910.2
# 2   2000             31059.1                     14041.6
# 3   2001              -793.6                      7492.8
# 4   2002               436.8                      -573.2
#
#    Dienste - Transporte und Kommunikation.3  Dienste - Übrige Dienste.3
# 0                                     859.3                        62.0
# 1                                    3524.3                      4121.3
# 2                                     196.3                      2265.6
# 3                                    1521.1                      1528.0
# 4                                   -1382.8                     -1220.4

# %%
# Draw a graph with pandas and keep what's returned
ax = df.plot(kind='bar', x='Jahre',
             y=['Dienste - Banken.3',
               'Dienste - Versicherungen.3',
               'Dienste - Transporte und Kommunikation.3',
               'Dienste - Übrige Dienste.3'],
             figsize=(15,10), fontsize=14)

# Set the x scale because otherwise it goes into weird negative numbers
# ax.set_xlim((0, 70000))

# Set the x-axis label
ax.set_xlabel("Jahre", fontname="Arial", fontsize=14, fontweight='bold')

# Set the y-axis label
ax.set_ylabel("Millionen Franken", fontsize=14)

# Set the y-axis titel
ax.set_title("Dienste", fontname="Arial", fontsize=22)

ax.grid(b=None, which='major', axis='both', color='#DFEBEC', linestyle='--', linewidth=1)

ax.set_axisbelow(True)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------

# %%
data = {'Beteiligungskapital'}

df = pd.DataFrame(data, index = ['Kapitalart', 'Selektoren und Branchen','1998', '1999', '2000', '2001', '2001', '2002',
                                 '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
                                 '2012', '2013', '2014', '2015', '2016'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-db81433edce5> in <module>()
#       3 df = pd.DataFrame(data, index = ['Kapitalart', 'Selektoren und Branchen','1998', '1999', '2000', '2001', '2001', '2002',
#       4                                  '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
# ----> 5                                  '2012', '2013', '2014', '2015', '2016'])
#       6 df
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
data = {'Beteiligungskapital ohne reinvestierte Erträge': [2]}


df = pd.DataFrame(data, index = ['Kapitalart', 'Selektoren und Branchen','1998', '1999', '2000', '2001', '2001', '2002',
                                 '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
                                 '2012', '2013', '2014', '2015', '2016'])
df





df_irn = df[data]
df_irn.head(3)


df_irn.data.value_counts().sort_index().plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-e3eeaab83f74> in <module>()
#      11
#      12
# ---> 13 df_irn = df[data]
#      14 df_irn.head(3)
#      15
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...

# %%
df.drop([1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-cb1e1902e1a4> in <module>()
# ----> 1 df.drop([1])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
data = {}
df = pd.DataFrame(data, index = ['Kapitalart', 'Sektoren und Branchen', 'Leerzeile',
                                 '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2205',
                                '2006', '2007', '2008', '2009', '2010', '2011', '2012',
                                '2013', '2014', '2015', '2016'])
df


'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'year': [2012, 2012, 2013, 2014, 2014], 
        'reports': [4, 24, 31, 2, 3]
# Out:
#   File "<ipython-input-54-8e113c6055d8>", line 9
#     'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#                                                      ^
# SyntaxError: invalid syntax

# %%
data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'year': [2012, 2012, 2013, 2014, 2014], 
        'reports': [4, 24, 31, 2, 3]}

df = pd.DataFrame(data, index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa', 'Yuma'])
df
# Out:
#              name  year  reports
# Cochice     Jason  2012        4
# Pima        Molly  2012       24
# Santa Cruz   Tina  2013       31
# Maricopa     Jake  2014        2
# Yuma          Amy  2014        3

# %%
df = df.transpose()

# %%
df
# Out:
#         Cochice   Pima Santa Cruz Maricopa  Yuma
# name      Jason  Molly       Tina     Jake   Amy
# year       2012   2012       2013     2014  2014
# reports       4     24         31        2     3

# %%
data = ()

# %%
df.set_index(['1998', '1999', '2000', '2001',
              '2002', '2003', '2004', '2005', '2006',
              '2007', '2008', '2009', '2010'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1998'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-8f15fde73415> in <module>()
# ...
