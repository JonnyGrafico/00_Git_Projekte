# %% [markdown]
# # Schweizerische Direktinvestitionen im Ausland

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Länder

# %% [markdown]
# ## Europa

# %%
df = pd.read_excel('001_snb-länder.xlsx', index_col=0, header=0)

# %%
df.fillna(0).head()
# Out:
#        Alle Länder - Total  Alle Länder - Europa - Total  \
# Jahre
# 1998               27209.2                       10787.2
# 1999               49986.2                       23637.8
# 2000               75445.8                       29378.4
# 2001               30916.2                       13461.5
# 2002               12785.0                       10274.0
#
#        Alle Länder - Europa - Baltische Länder  \
# Jahre
# 1998                                      49.1
# 1999                                       2.2
# 2000                                      20.8
# 2001                                      -4.3
# 2002                                      78.5
#
#        Alle Länder - Europa - Belgien  Alle Länder - Europa - Bulgarien  \
# Jahre
# 1998                            348.7                              12.0
# 1999                           1178.5                               6.3
# 2000                           4428.9                             -20.9
# ...

# %%
#df.columns

# %%
df.columns = df.columns.str.strip().str.replace(
    'Alle Länder - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")
df.columns = df.columns.str.strip('_')
#df.columns

# %%
alle_länder = df[['Europa - Total',
       'Nordamerika - Total',
       'Mittel- und Südamerika - Total',
       'Asien - Total',
       'Afrika - Total',
       'Ozeanien - Total',]]
alle_länder.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Kontinente")

# %%
df = pd.read_excel('001_snb-länder.xlsx', index_col=0, header=0)
df.fillna(0).head()
# Out:
#        Alle Länder - Total  Alle Länder - Europa - Total  \
# Jahre
# 1998               27209.2                       10787.2
# 1999               49986.2                       23637.8
# 2000               75445.8                       29378.4
# 2001               30916.2                       13461.5
# 2002               12785.0                       10274.0
#
#        Alle Länder - Europa - Baltische Länder  \
# Jahre
# 1998                                      49.1
# 1999                                       2.2
# 2000                                      20.8
# 2001                                      -4.3
# 2002                                      78.5
#
#        Alle Länder - Europa - Belgien  Alle Länder - Europa - Bulgarien  \
# Jahre
# 1998                            348.7                              12.0
# 1999                           1178.5                               6.3
# 2000                           4428.9                             -20.9
# ...

# %%
df.columns = df.columns.str.strip().str.replace(
    'Alle Länder - Europa - ', '_').str.replace(
    'Alle Länder - Nordamerika - ', '_').str.replace(
    'Alle Länder - Mittel- und Südamerika - ', '_').str.replace(
    'Alle Länder - Asien - ', '_').str.replace(
    'Alle Länder - Afrika - ', '_').str.replace(
    'Alle Länder - Ozeanien - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df.columns = df.columns.str.strip('_').str.strip(')')

# %%
alle_länder = df[['Alle Länder - Total',
       'Pro memoria: Grundstücks- und Wohnungswesen',
       'Pro memoria: Alle Länder inkl. Grundstücks- und Wohnungswesen']]
alle_länder.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Alle Länder total, Grundstücks- und Wohnungswesen")

# %%
df.columns
# Out:
# Index(['Alle Länder - Total', 'Total', 'Baltische Länder', 'Belgien',
#        'Bulgarien', 'Dänemark', 'Deutschland', 'Finnland', 'Frankreich',
#        'Griechenland', 'Irland', 'Italien', 'Kroatien', 'Luxemburg',
#        'Niederlande', 'Norwegen', 'Österreich', 'Polen', 'Portugal',
#        'Rumänien', 'Russische Föderation', 'Schweden', 'Slowakei', 'Spanien',
#        'Tschechische Republik', 'Türkei', 'Ukraine', 'Ungarn',
#        'Vereinigtes Königreich', 'Offshore-Finanzzentren Europa', 'EU',
#        'Übriges Europa', 'Total', 'Kanada', 'Vereinigte Staaten', 'Total',
#        'Argentinien', 'Bolivien', 'Brasilien', 'Chile', 'Costa Rica',
#        'Ecuador', 'Guatemala', 'Kolumbien', 'Mexiko', 'Peru', 'Uruguay',
#        'Venezuela', 'Offshore-Finanzzentren Mittel- und Südamerika', 'Total',
#        'Bangladesch', 'China', 'Hongkong', 'Indien', 'Indonesien', 'Israel',
#        'Japan', 'Korea Republik Süd-', 'Malaysia', 'Pakistan', 'Philippinen',
# ...

# %%
europa = df[['Baltische Länder', 'Belgien',
       'Bulgarien', 'Dänemark', 'Deutschland', 'Finnland', 'Frankreich',
       'Griechenland', 'Irland', 'Italien', 'Kroatien', 'Luxemburg',
       'Niederlande', 'Norwegen', 'Österreich', 'Polen', 'Portugal',
       'Rumänien', 'Russische Föderation', 'Schweden', 'Slowakei', 'Spanien',
       'Tschechische Republik', 'Türkei', 'Ukraine', 'Ungarn',
       'Vereinigtes Königreich', 'Offshore-Finanzzentren Europa', 'EU',
       'Übriges Europa']]
europa.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Europa")

# %%
nordamerika = df[['Kanada', 'Vereinigte Staaten']]
nordamerika.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Nordamerika")

# %%
mittelundsüdamerika = df[['Argentinien', 'Bolivien', 'Brasilien', 'Chile', 'Costa Rica',
       'Ecuador', 'Guatemala', 'Kolumbien', 'Mexiko', 'Peru', 'Uruguay',
       'Venezuela', 'Offshore-Finanzzentren Mittel- und Südamerika']]
mittelundsüdamerika.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Mittel- und Südamerika, mit Offshore")

# %%
mittelundsüdamerika = df[['Argentinien', 'Bolivien', 'Brasilien', 'Chile', 'Costa Rica',
       'Ecuador', 'Guatemala', 'Kolumbien', 'Mexiko', 'Peru', 'Uruguay',
       'Venezuela']]
mittelundsüdamerika.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Mittel- und Südamerika – ohne Offshore")

# %%
asien = df[['Bangladesch', 'China', 'Hongkong', 'Indien', 'Indonesien', 'Israel',
       'Japan', 'Korea Republik Süd-', 'Malaysia', 'Pakistan', 'Philippinen',
       'Saudi-Arabien', 'Singapur', 'Sri Lanka', 'Taiwan', 'Thailand',
       'Vereinigte Arabische Emirate', 'Vietnam']]
asien.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Asien")

# %%
afrika = df[['Côte dIvoire', 'Kenia', 'Marokko', 'Nigeria', 'Südafrika', 'Tunesien']]
afrika.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Afrika")

# %%
ozeanien = df[['Australien', 'Neuseeland']]
ozeanien.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Ozeanien")

# %%
offshore = df[['Offshore-Finanzzentren Europa', 'Offshore-Finanzzentren Mittel- und Südamerika']]
offshore.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar', figsize=(15,10),
    fontsize=14,
    title="DI: Offshore-Finanzzentren")
