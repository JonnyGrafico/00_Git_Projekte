# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
df = pd.read_excel('00_snb-data-fdiaustabsa-de-all-20171215_0900.xlsx')

# %%
# df.columns = df.columns.str.strip('_').str.strip(')')df.head()

# %%
df.shape
# Out:
# (37, 77)

# %%
df = df.fillna('XX')
df.head()
# Out:
#         Datenportal der Schweizerischen Nationalbank            Unnamed: 1  \
# 0  Hinweis: Die vorliegende Datei enthält die Ang...                    XX
# 1  Für das bessere Verständnis der Werte in diese...                    XX
# 2  Aus urheberrechtlichen Gründen kann das Herunt...                    XX
# 3                                                 XX                    XX
# 4                                            Einheit  In Millionen Franken
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0         XX         XX         XX         XX         XX         XX
# 1         XX         XX         XX         XX         XX         XX
# 2         XX         XX         XX         XX         XX         XX
# 3         XX         XX         XX         XX         XX         XX
# 4         XX         XX         XX         XX         XX         XX
#
#   Unnamed: 8 Unnamed: 9     ...     Unnamed: 67 Unnamed: 68 Unnamed: 69  \
# ...

# %%
# df1 = df[['Kapitalart', 'Beteiligungskapital ohne reinvestierte Erträge']]
# df1

# %%
# df1.set_index("Kapitalart", inplace=True)
# df1.fillna(0).head(5)

# %%
# df.drop([2])

# %%
new_header = df.iloc[15] #grab the first row for the header
df = df[16:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df.head()
# Out:
# 15 Kapitalart Beteiligungskapital ohne reinvestierte Erträge  \
# 16      Jahre                              Industrie - Total
# 17         XX                   EPB@SNB.fdiaustabsa{D0_0,T0}
# 18       1998                                           6374
# 19       1999                                           4606
# 20       2000                                        17634.5
#
# 15 Beteiligungskapital ohne reinvestierte Erträge  \
# 16           Industrie - Textilien und Bekleidung
# 17                  EPB@SNB.fdiaustabsa{D0_0,TUB}
# 18                                          285.5
# 19                                            440
# 20                                             19
#
# 15 Beteiligungskapital ohne reinvestierte Erträge  \
# 16             Industrie - Chemie und Kunststoffe
# 17                  EPB@SNB.fdiaustabsa{D0_0,CUK}
# 18                                         3829.8
# 19                                          198.5
# ...

# %%
df.drop([17]).head()
# Out:
# 15 Kapitalart Beteiligungskapital ohne reinvestierte Erträge  \
# 16      Jahre                              Industrie - Total
# 18       1998                                           6374
# 19       1999                                           4606
# 20       2000                                        17634.5
# 21       2001                                         8012.8
#
# 15 Beteiligungskapital ohne reinvestierte Erträge  \
# 16           Industrie - Textilien und Bekleidung
# 18                                          285.5
# 19                                            440
# 20                                             19
# 21                                         -224.9
#
# 15 Beteiligungskapital ohne reinvestierte Erträge  \
# 16             Industrie - Chemie und Kunststoffe
# 18                                         3829.8
# 19                                          198.5
# 20                                         7680.3
# ...

# %%
#df.columns

# %%
df = df[['Kapitalart', 'Beteiligungskapital ohne reinvestierte Erträge']]
df.head()
# Out:
# 15 Kapitalart Beteiligungskapital ohne reinvestierte Erträge  \
# 16      Jahre                              Industrie - Total
# 17         XX                   EPB@SNB.fdiaustabsa{D0_0,T0}
# 18       1998                                           6374
# 19       1999                                           4606
# 20       2000                                        17634.5
#
# 15 Beteiligungskapital ohne reinvestierte Erträge  \
# 16           Industrie - Textilien und Bekleidung
# 17                  EPB@SNB.fdiaustabsa{D0_0,TUB}
# 18                                          285.5
# 19                                            440
# 20                                             19
#
# 15 Beteiligungskapital ohne reinvestierte Erträge  \
# 16             Industrie - Chemie und Kunststoffe
# 17                  EPB@SNB.fdiaustabsa{D0_0,CUK}
# 18                                         3829.8
# 19                                          198.5
# ...

# %%
# df = df.set_index('Kapitalart')
# df.head(5)

# %%
#ohne.columns

# %%
# df = df.iloc[0:21, 0:21]
# df.head()

# %%
new_header2 = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header2 #set the header row as the df header
df.head()
# Out:
# 16 Jahre             Industrie - Total Industrie - Textilien und Bekleidung  \
# 17    XX  EPB@SNB.fdiaustabsa{D0_0,T0}        EPB@SNB.fdiaustabsa{D0_0,TUB}
# 18  1998                          6374                                285.5
# 19  1999                          4606                                  440
# 20  2000                       17634.5                                   19
# 21  2001                        8012.8                               -224.9
#
# 16 Industrie - Chemie und Kunststoffe Industrie - Metalle und Maschinen  \
# 17      EPB@SNB.fdiaustabsa{D0_0,CUK}     EPB@SNB.fdiaustabsa{D0_0,MUM}
# 18                             3829.8                             819.5
# 19                              198.5                             650.8
# 20                             7680.3                            1271.6
# 21                             2583.7                            1707.4
#
# 16 Industrie - Elektronik, Energie, Optik und Uhren  \
# ...

# %%
#df.columns = df.columns.str.replace('NaN', '_')

# %%
# df.drop(['XX']).head()

# %%
df.shape
# Out:
# (20, 21)

# %%
df.columns
# Out:
# Index(['Jahre', 'Industrie - Total', 'Industrie - Textilien und Bekleidung',
#        'Industrie - Chemie und Kunststoffe',
#        'Industrie - Metalle und Maschinen',
#        'Industrie - Elektronik, Energie, Optik und Uhren',
#        'Industrie - Übrige Industrien und Bau', 'Dienste - Total',
#        'Dienste - Handel',
#        'Dienste - Finanz- und Holdinggesellschaften - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities',
#        'Dienste - Banken', 'Dienste - Versicherungen',
#        'Dienste - Transporte und Kommunikation', 'Dienste - Übrige Dienste',
#        'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        'Pro memoria: Grundstücks- und Wohnungswesen',
# ...

# %%
#df.columns = df.columns.str.replace(' ', 'Jahre')

# %%
df = df[['Jahre', 'Industrie - Total', 'Industrie - Textilien und Bekleidung',
       'Industrie - Chemie und Kunststoffe']]
df.head()
# Out:
# 16 Jahre             Industrie - Total Industrie - Textilien und Bekleidung  \
# 17    XX  EPB@SNB.fdiaustabsa{D0_0,T0}        EPB@SNB.fdiaustabsa{D0_0,TUB}
# 18  1998                          6374                                285.5
# 19  1999                          4606                                  440
# 20  2000                       17634.5                                   19
# 21  2001                        8012.8                               -224.9
#
# 16 Industrie - Chemie und Kunststoffe
# 17      EPB@SNB.fdiaustabsa{D0_0,CUK}
# 18                             3829.8
# 19                              198.5
# 20                             7680.3
# 21                             2583.7

# %%
#df.drop(['XX']).head()

# %%
df.columns
# Out:
# Index(['Jahre', 'Industrie - Total', 'Industrie - Textilien und Bekleidung',
#        'Industrie - Chemie und Kunststoffe'],
#       dtype='object', name=16)

# %%
df = df.set_index('Jahre')
df.head(5)
# Out:
# 16                Industrie - Total Industrie - Textilien und Bekleidung  \
# Jahre
# XX     EPB@SNB.fdiaustabsa{D0_0,T0}        EPB@SNB.fdiaustabsa{D0_0,TUB}
# 1998                           6374                                285.5
# 1999                           4606                                  440
# 2000                        17634.5                                   19
# 2001                         8012.8                               -224.9
#
# 16    Industrie - Chemie und Kunststoffe
# Jahre
# XX         EPB@SNB.fdiaustabsa{D0_0,CUK}
# 1998                              3829.8
# 1999                               198.5
# 2000                              7680.3
# 2001                              2583.7

# %%
df.drop(['XX']).head()
# Out:
# 16    Industrie - Total Industrie - Textilien und Bekleidung  \
# Jahre
# 1998               6374                                285.5
# 1999               4606                                  440
# 2000            17634.5                                   19
# 2001             8012.8                               -224.9
# 2002            11437.2                                 37.3
#
# 16    Industrie - Chemie und Kunststoffe
# Jahre
# 1998                              3829.8
# 1999                               198.5
# 2000                              7680.3
# 2001                              2583.7
# 2002                                3444

# %%
fig = df.iloc[2:5].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Industrie - Total', 'Industrie - Textilien und Bekleidung',
       'Industrie - Chemie und Kunststoffe'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Industrie und Dienste',
    legend=False)
    
fig.set_title('Direktinvestitionen: Industrie und Dienste', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
    
fig.set_title('Direktinvestitionen: Dienste – Holdings', fontname="Verdana", fontsize=30, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(0, -0.3), fontsize=20)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')



#df.iloc[0:20].apply(lambda x: x/1000)

# %%
new_header2 = ohne.iloc[0] #grab the first row for the header
ohne = df[2:] #take the data less the header row
ohne.columns = new_header2 #set the header row as the df header
ohne.head()
# Out:
# 1999         4606.0 440.0   198.5
# Kapitalart
# 1999           4606    440   198.5
# 2000        17634.5     19  7680.3
# 2001         8012.8 -224.9  2583.7
# 2002        11437.2   37.3    3444
# 2003         2180.9  421.5  -225.3

# %%
ohne.drop([17]).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1422-f9e199d1e0a4> in <module>
# ----> 1 ohne.drop([17]).head()
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
ohne.columns
# Out:
# Float64Index([4606.0, 440.0, 198.5], dtype='float64', name='1999')

# %%
ohne.columns = ohne.columns.str.strip().str.replace(
    'Industrie - ', '_').str.replace(
    'Nan - ', 'Nichts').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

ohne.columns = ohne.columns.str.strip('_').str.strip(')')
ohne.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1353-6e711b6cc91e> in <module>
# ----> 1 ohne.columns = ohne.columns.str.strip().str.replace(
#       2     'Industrie - ', '_').str.replace(
#       3     'Nan - ', 'Nichts').str.replace(
#       4     '(', '').str.replace('', '').str.replace("'", "")
#       5
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    1893
# ...

# %%
df1 = df1.set_index('Kapitalart')
df1.fillna(0).head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Kapitalart'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1217-6d657d9190cd> in <module>
# ...

# %%
# df.columns

# %%
new_header = df.iloc[15] #grab the first row for the header
df = df[16:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df.head()
# Out:
# 2012         9014.2  1073.2   2199.3
# Kapitalart
# 2013        -3108.7  -968.3  -1846.1
# 2014       -6511.98  -541.7 -151.989
# 2015        1856.29  -454.9  3072.03
# 2016        20677.6  91.114   1631.6

# %%
df1.columns = df1.columns.str.strip().str.replace(
    'Industrie - ', '_').str.replace(
    'Nan - ', 'Nichts').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df1.columns = df1.columns.str.strip('_').str.strip(')')

# %%
df1
# Out:
# 15                     Beteiligungskapital ohne reinvestierte Erträge  \
# Kapitalart
# Sektoren und Branchen                               Industrie - Total
# NaN                                      EPB@SNB.fdiaustabsa{D0_0,T0}
# 1998                                                             6374
# 1999                                                             4606
# 2000                                                          17634.5
# 2001                                                           8012.8
# 2002                                                          11437.2
# 2003                                                           2180.9
# 2004                                                          11829.5
# 2005                                                          10192.9
# 2006                                                          30913.1
# 2007                                                           9862.1
# ...
