# %% [markdown]
# # Schweizerische Direktinvestitionen im Ausland

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Kapitalart, Sektoren und Branchen

# %%
#df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx')

# %%
#df.head()

# %%
#df.tail()

# %%
df = df.set_index('Jahre')
df.fillna(0).head(5)
# Out:
#        Industrie  Industrie - Textilien und Bekleidung  \
# Jahre
# 1998      6374.0                                 285.5
# 1999      4606.0                                 440.0
# 2000     17634.5                                  19.0
# 2001      8012.8                                -224.9
# 2002     11437.2                                  37.3
#
#        Industrie - Chemie und Kunststoffe  Industrie - Metalle und Maschinen  \
# Jahre
# 1998                               3829.8                              819.5
# 1999                                198.5                              650.8
# 2000                               7680.3                             1271.6
# 2001                               2583.7                             1707.4
# 2002                               3444.0                              431.8
#
#        Industrie - Elektronik, Energie, Optik und Uhren  \
# Jahre
# 1998                                              108.0
# ...

# %%
df.columns
# Out:
# Index(['Industrie', 'Industrie - Textilien und Bekleidung',
#        'Industrie - Chemie und Kunststoffe',
#        'Industrie - Metalle und Maschinen',
#        'Industrie - Elektronik, Energie, Optik und Uhren',
#        'Industrie - Übrige Industrien und Bau', 'Dienste', 'Dienste - Handel',
#        'Dienste - Finanz- und Holdinggesellschaften - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities',
#        'Dienste - Banken', 'Dienste - Versicherungen',
#        'Dienste - Transporte und Kommunikation', 'Dienste - Übrige Dienste',
#        'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        'Pro memoria: Grundstücks- und Wohnungswesen',
# ...

# %%
# df.columns = df.columns.str.strip().str.replace(
#     'Industrie - ', '_').str.replace(
#     'Dienste - ', '_').str.replace(
#     'Dienste - Finanz- und Holdinggesellschaften - ', '_').str.replace(
#     'Alle Länder - Asien - ', '_').str.replace(
#     '(', '').str.replace('', '').str.replace("'", "")

# df.columns = df.columns.str.strip('_').str.strip(')')

# %%
#df.columns

# %%
df_industrie_dienste = df[['Industrie','Dienste']]
df_industrie_dienste.iloc[15:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_industrie = df[['Industrie - Textilien und Bekleidung',
    'Industrie - Chemie und Kunststoffe',
    'Industrie - Metalle und Maschinen',
    'Industrie - Elektronik, Energie, Optik und Uhren',
    'Industrie - Übrige Industrien und Bau']]
df_industrie.iloc[15:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_dienste_holdings = df[['Dienste - Handel',
    'Dienste - Finanz- und Holdinggesellschaften - Total',
    'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
    'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3',
    'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities.3']]
df_dienste_holdings.iloc[15:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_dienste = df[['Dienste - Banken.3',
    'Dienste - Versicherungen.3',
    'Dienste - Transporte und Kommunikation.3',
    'Dienste - Übrige Dienste.3']]
df_dienste.iloc[15:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_div_total = df[['Total.3', 'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften.3']]
df_div_total.iloc[0:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %% [markdown]
# # Schweizerische Direkinvestitionen nach Ländern

# %% [markdown]
# ## Europa

# %%
#df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
df = pd.read_excel('snb-data-fdiaustlanda-de-all-20171215_0900.xlsx')

# %%
df = df.set_index('Jahre')
df.fillna(0).head(5)
# Out:
#        Alle Länder - Total  Alle Länder - Europa - Total  \
# Jahre
# 1998               27209.2                       10787.2
# 1999               49986.2                       23637.8
# 2000               75445.8                       29378.4
# 2001               30916.2                       13461.5
# 2002               12785.0                       10274.0
#
#        Alle Länder - Europa - Baltische Länder  \
# Jahre
# 1998                                      49.1
# 1999                                       2.2
# 2000                                      20.8
# 2001                                      -4.3
# 2002                                      78.5
#
#        Alle Länder - Europa - Belgien  Alle Länder - Europa - Bulgarien  \
# Jahre
# 1998                            348.7                              12.0
# 1999                           1178.5                               6.3
# 2000                           4428.9                             -20.9
# ...

# %%
#df.columns

# %%
df.columns = df.columns.str.strip().str.replace(
    'Alle Länder - Europa - ', '_').str.replace(
    'Alle Länder - Nordamerika - ', '_').str.replace(
    'Alle Länder - Mittel- und Südamerika - ', '_').str.replace(
    'Alle Länder - Asien - ', '_').str.replace(
    'Alle Länder - Afrika - ', '_').str.replace(
    'Alle Länder - Ozeanien - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df.columns = df.columns.str.strip('_').str.strip(')')

# %%
#df.columns

# %%
df_europa = df[['Baltische Länder', 'Belgien',
       'Bulgarien', 'Dänemark', 'Deutschland', 'Finnland', 'Frankreich',
       'Griechenland', 'Irland', 'Italien', 'Kroatien', 'Luxemburg',
       'Niederlande', 'Norwegen', 'Österreich', 'Polen', 'Portugal',
       'Rumänien', 'Russische Föderation', 'Schweden', 'Slowakei', 'Spanien',
       'Tschechische Republik', 'Türkei', 'Ukraine', 'Ungarn',
       'Vereinigtes Königreich', 'Offshore-Finanzzentren Europa', 'EU',
       'Übriges Europa']]

df_europa.iloc[15:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_nordamerika = df[['Kanada', 'Vereinigte Staaten']]
df_nordamerika.iloc[0:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_mittel_und_südamerika = df[['Argentinien', 'Bolivien', 'Brasilien', 'Chile', 'Costa Rica',
       'Ecuador', 'Guatemala', 'Kolumbien', 'Mexiko', 'Peru', 'Uruguay',
       'Venezuela', 'Offshore-Finanzzentren Mittel- und Südamerika']]

df_mittel_und_südamerika.iloc[15:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_asien = df[['Bangladesch', 'China', 'Hongkong', 'Indien', 'Indonesien', 'Israel',
       'Japan', 'Korea Republik Süd-', 'Malaysia', 'Pakistan', 'Philippinen',
       'Saudi-Arabien', 'Singapur', 'Sri Lanka', 'Taiwan', 'Thailand',
       'Vereinigte Arabische Emirate', 'Vietnam']]
df_asien.iloc[15:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_afrika = df[['Ägypten','Côte dIvoire', 'Kenia', 'Marokko', 'Nigeria', 'Südafrika', 'Tunesien']]
df_afrika.iloc[0:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df_ozeanien = df[['Australien', 'Neuseeland']]
df_ozeanien.iloc[0:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(10,8))

# %%
df = pd.read_excel('snb-data-fdiaustlanda-de-all-20171215_0900.xlsx')

df = df.set_index('Jahre')
df.fillna(0)

df.columns = df.columns.str.strip().str.replace(
    'Alle Länder - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df.columns = df.columns.str.strip('_')

df_kontinente = df[['Europa - Total', 'Nordamerika - Total', 'Mittel- und Südamerika - Total', 'Asien - Total', 'Afrika - Total', 'Ozeanien - Total']]
df_kontinente.iloc[0:19].apply(lambda x: x/1000).plot(kind='bar', figsize=(20,8))

# %%
# df_pivoted_100 = df_pivoted.apply(lambda row: row / row_0 * 100, axis=1)

# %%
# i = grafik[]

# Zuerst kreieren wir nur die Figure
fig = plt.figure(figsize=(10,20))

# Danach die einzelnen Subplots
ax1 = fig.add_subplot(1, 1, 1) # total 1 Zeile, total 2 Spalten, Subplot Nr. 1
ax2 = fig.add_subplot(2, 1, 2) # total 1 Zeile, total 2 Spalten, Subplot Nr. 2

# Und schliesslich füllen wir die Subplots mit Inhalt
df_kontinente.plot(kind='bar', figsize=(20,15), title="Kontinente", ax=ax1)
df_europa.plot(kind='bar', title="Europa", ax=ax2)

# # Hier formatieren wir die x-Achse für Plot 1
# ax1.xaxis.set_major_locator(mdates.MonthLocator())
# ax1.xaxis.set_major_formatter(mdates.DateFormatter('%m'))
# ax1.xaxis.set_minor_locator(ticker.NullLocator())

# # Hier formatieren wir die x-Achse für Plot 2
# ax2.xaxis.set_major_locator(mdates.MonthLocator())
# ax2.xaxis.set_major_formatter(mdates.DateFormatter('%m'))
# ax2.xaxis.set_minor_locator(ticker.NullLocator())

# %% [markdown]
# ##

# %%
df_afrika = df[['Ägypten','Côte dIvoire', 'Kenia', 'Marokko', 'Nigeria', 'Südafrika', 'Tunesien']]
df_afrika.iloc[0:19].apply(lambda x: x/1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-4f9bfd8a593a> in <module>
# ----> 1 df_afrika = df[['Ägypten','Côte dIvoire', 'Kenia', 'Marokko', 'Nigeria', 'Südafrika', 'Tunesien']]
#       2 df_afrika.iloc[0:19].apply(lambda x: x/1000)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# ...

# %%
df_ozeanien = df[['Australien', 'Neuseeland']]
df_ozeanien.iloc[0:19].apply(lambda x: x/1000)

# %%
# i = grafik[]

# Zuerst kreieren wir nur die Figure
fig = plt.figure(figsize=(10,20))

# Danach die einzelnen Subplots
ax1 = fig.add_subplot(1, 1, 1) # total 1 Zeile, total 2 Spalten, Subplot Nr. 1
ax2 = fig.add_subplot(2, 1, 2) # total 1 Zeile, total 2 Spalten, Subplot Nr. 2

# Und schliesslich füllen wir die Subplots mit Inhalt
df_afrika.plot(kind='bar', figsize=(20,15), title="Afrika", ax=ax1)
df_ozeanien.plot(kind='bar', title="Ozeanien", ax=ax2)

# # Hier formatieren wir die x-Achse für Plot 1
# ax1.xaxis.set_major_locator(mdates.MonthLocator())
# ax1.xaxis.set_major_formatter(mdates.DateFormatter('%m'))
# ax1.xaxis.set_minor_locator(ticker.NullLocator())

# # Hier formatieren wir die x-Achse für Plot 2
# ax2.xaxis.set_major_locator(mdates.MonthLocator())
# ax2.xaxis.set_major_formatter(mdates.DateFormatter('%m'))
# ax2.xaxis.set_minor_locator(ticker.NullLocator())

# %%
# ax = df_kon.plot(kind='bar')
# df_eu.plot(ax=ax)

# %%
# fig, axes = plt.subplots(nrows=2, ncols=2)

# df_kon.plot(ax=axes[0,0], kind='bar', figsize=(25,15))
# df_eu.plot(ax=axes[1,0])

# %%
# fig, ax = plt.subplots(figsize=(15,7))
# data.groupby(['date','type']).count()['amount'].unstack().plot(ax=ax)
# ax.set_xlabel('Date')
# ax.set_ylabel('Number of transactions')
