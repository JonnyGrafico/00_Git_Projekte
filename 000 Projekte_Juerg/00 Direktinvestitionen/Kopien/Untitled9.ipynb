# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../snb-data-fdiaustabsa-de-all-20171215_0900.xslx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-e8081ad08b43> in <module>
# ----> 1 df = pd.read_excel('../snb-data-fdiaustabsa-de-all-20171215_0900.xslx')
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ...

# %%
df
# Out:
#       Beteiligungskapital ohne reinvestierte Erträge  \
# Jahre                              Industrie - Total
# 1998                                            6374
# 1999                                            4606
# 2000                                         17634.5
# 2001                                          8012.8
# 2002                                         11437.2
# 2003                                          2180.9
# 2004                                         11829.5
# 2005                                         10192.9
# 2006                                         30913.1
# 2007                                          9862.1
# 2008                                         14370.8
# 2009                                             8.2
# 2010                                          1400.5
# 2011                                         -8520.4
# 2012                                          9014.2
# 2013                                         -3108.7
# ...
