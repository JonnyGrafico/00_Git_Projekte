# %% [markdown]
# # Schweizerische Direktinvestitionen im Ausland

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Kapitalart, Sektoren und Branchen

# %%
#df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx')

# %%
#df.head()

# %%
#df.tail()

# %%
df = df.set_index('Jahre')
df.fillna(0).head(5)
# Out:
#        Industrie  Industrie - Textilien und Bekleidung  \
# Jahre
# 1998      6374.0                                 285.5
# 1999      4606.0                                 440.0
# 2000     17634.5                                  19.0
# 2001      8012.8                                -224.9
# 2002     11437.2                                  37.3
#
#        Industrie - Chemie und Kunststoffe  Industrie - Metalle und Maschinen  \
# Jahre
# 1998                               3829.8                              819.5
# 1999                                198.5                              650.8
# 2000                               7680.3                             1271.6
# 2001                               2583.7                             1707.4
# 2002                               3444.0                              431.8
#
#        Industrie - Elektronik, Energie, Optik und Uhren  \
# Jahre
# 1998                                              108.0
# ...

# %%
df.columns
# Out:
# Index(['Industrie', 'Industrie - Textilien und Bekleidung',
#        'Industrie - Chemie und Kunststoffe',
#        'Industrie - Metalle und Maschinen',
#        'Industrie - Elektronik, Energie, Optik und Uhren',
#        'Industrie - Übrige Industrien und Bau', 'Dienste', 'Dienste - Handel',
#        'Dienste - Finanz- und Holdinggesellschaften - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities',
#        'Dienste - Banken', 'Dienste - Versicherungen',
#        'Dienste - Transporte und Kommunikation', 'Dienste - Übrige Dienste',
#        'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        'Pro memoria: Grundstücks- und Wohnungswesen',
# ...

# %%
# df.columns = df.columns.str.strip().str.replace(
#     'Industrie - ', '_').str.replace(
#     'Dienste - ', '_').str.replace(
#     'Dienste - Finanz- und Holdinggesellschaften - ', '_').str.replace(
#     'Alle Länder - Asien - ', '_').str.replace(
#     '(', '').str.replace('', '').str.replace("'", "")

# df.columns = df.columns.str.strip('_').str.strip(')')

# %%
#df.columns

# %%
industrie_dienste = df[['Industrie','Dienste']]
industrie_dienste.apply(lambda x: x/1000).head(5)
# Out:
#        Industrie  Dienste
# Jahre
# 1998      6.3740  10.5748
# 1999      4.6060  19.2291
# 2000     17.6345  38.3778
# 2001      8.0128  13.9826
# 2002     11.4372  13.1464

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Industrie','Dienste'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Industrie und Dienste',
    legend=False)
    
fig.set_title('Direktinvestitionen: Industrie und Dienste', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
industrie = df[['Industrie - Textilien und Bekleidung',
    'Industrie - Chemie und Kunststoffe',
    'Industrie - Metalle und Maschinen',
    'Industrie - Elektronik, Energie, Optik und Uhren',
    'Industrie - Übrige Industrien und Bau']]
industrie.apply(lambda x: x/1000).head(5)
# Out:
#        Industrie - Textilien und Bekleidung  \
# Jahre
# 1998                                 0.2855
# 1999                                 0.4400
# 2000                                 0.0190
# 2001                                -0.2249
# 2002                                 0.0373
#
#        Industrie - Chemie und Kunststoffe  Industrie - Metalle und Maschinen  \
# Jahre
# 1998                               3.8298                             0.8195
# 1999                               0.1985                             0.6508
# 2000                               7.6803                             1.2716
# 2001                               2.5837                             1.7074
# 2002                               3.4440                             0.4318
#
#        Industrie - Elektronik, Energie, Optik und Uhren  \
# Jahre
# 1998                                             0.1080
# 1999                                             1.1111
# ...

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Industrie - Textilien und Bekleidung',
       'Industrie - Chemie und Kunststoffe',
       'Industrie - Metalle und Maschinen',
       'Industrie - Elektronik, Energie, Optik und Uhren',
       'Industrie - Übrige Industrien und Bau'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Industrie – Sektionen',
    legend=False)
    
fig.set_title('Direktinvestitionen: Industrie – Sektionen', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(0, -0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
dienste_holdings = df[['Dienste - Handel',
    'Dienste - Finanz- und Holdinggesellschaften - Total',
    'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
    'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3',
    'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities.3']]
dienste_holdings.apply(lambda x: x/1000).head(5)
# Out:
#        Dienste - Handel  Dienste - Finanz- und Holdinggesellschaften - Total  \
# Jahre
# 1998             0.3690                                             0.5655
# 1999             0.0528                                             3.7783
# 2000             0.1092                                             1.9007
# 2001             0.8909                                             0.1675
# 2002            -0.0902                                             3.7107
#
#        Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht  \
# Jahre
# 1998                                              1.1334
# 1999                                              0.1503
# 2000                                              2.0029
# 2001                                              1.3948
# 2002                                              2.3452
#
#        Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3  \
# Jahre
# ...

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Dienste - Handel',
       'Dienste - Finanz- und Holdinggesellschaften - Total',
       'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
       'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3',
       'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities.3'], 
    figsize=(25,15),
    grid=True,
    fontsize=22,
    title='Direktinvestitionen: Dienste – Holdings',
    legend=False)
    
fig.set_title('Direktinvestitionen: Dienste – Holdings', fontname="Verdana", fontsize=30, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(0, -0.3), fontsize=20)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
dienste = df[['Dienste - Banken.3',
    'Dienste - Versicherungen.3',
    'Dienste - Transporte und Kommunikation.3',
    'Dienste - Übrige Dienste.3']]
dienste.apply(lambda x: x/1000).head(5)
# Out:
#        Dienste - Banken.3  Dienste - Versicherungen.3  \
# Jahre
# 1998              -0.3212                      8.0344
# 1999               6.0820                      9.9102
# 2000              31.0591                     14.0416
# 2001              -0.7936                      7.4928
# 2002               0.4368                     -0.5732
#
#        Dienste - Transporte und Kommunikation.3  Dienste - Übrige Dienste.3
# Jahre
# 1998                                     0.8593                      0.0620
# 1999                                     3.5243                      4.1213
# 2000                                     0.1963                      2.2656
# 2001                                     1.5211                      1.5280
# 2002                                    -1.3828                     -1.2204

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Dienste - Banken.3',
    'Dienste - Versicherungen.3',
    'Dienste - Transporte und Kommunikation.3',
    'Dienste - Übrige Dienste.3'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Dienste – Banken, etc.',
    legend=False)
    
fig.set_title('Direktinvestitionen: Dienste – Banken, etc.', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
div_total = df[['Total.3', 'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften.3']]
div_total.apply(lambda x: x/1000).head(5)
# Out:
#        Total.3  \
# Jahre
# 1998   27.2092
# 1999   49.9862
# 2000   75.4458
# 2001   30.9162
# 2002   12.7850
#
#        Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften.3
# Jahre
# 1998                                             23.3393
# 1999                                             38.5066
# 2000                                             75.1882
# 2001                                             29.0315
# 2002                                              8.2494

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Total.3',
       'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften.3'], 
    figsize=(25,15),
    grid=True,
    fontsize=20,
    title='Direktinvestitionen: Total',
    legend=True)
    
fig.set_title('Direktinvestitionen: Total', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(0,-0.2), fontsize=20)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %% [markdown]
# # Schweizerische Direkinvestitionen nach Ländern

# %% [markdown]
# ## Europa

# %%
#df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
df = pd.read_excel('snb-data-fdiaustlanda-de-all-20171215_0900.xlsx')

# %%
df = df.set_index('Jahre')
df.fillna(0).head(5)
# Out:
#        Alle Länder - Total  Alle Länder - Europa - Total  \
# Jahre
# 1998               27209.2                       10787.2
# 1999               49986.2                       23637.8
# 2000               75445.8                       29378.4
# 2001               30916.2                       13461.5
# 2002               12785.0                       10274.0
#
#        Alle Länder - Europa - Baltische Länder  \
# Jahre
# 1998                                      49.1
# 1999                                       2.2
# 2000                                      20.8
# 2001                                      -4.3
# 2002                                      78.5
#
#        Alle Länder - Europa - Belgien  Alle Länder - Europa - Bulgarien  \
# Jahre
# 1998                            348.7                              12.0
# 1999                           1178.5                               6.3
# 2000                           4428.9                             -20.9
# ...

# %%
#df.columns

# %%
df.columns = df.columns.str.strip().str.replace(
    'Alle Länder - Europa - ', '_').str.replace(
    'Alle Länder - Nordamerika - ', '_').str.replace(
    'Alle Länder - Mittel- und Südamerika - ', '_').str.replace(
    'Alle Länder - Asien - ', '_').str.replace(
    'Alle Länder - Afrika - ', '_').str.replace(
    'Alle Länder - Ozeanien - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df.columns = df.columns.str.strip('_').str.strip(')')

# %%
#df.columns

# %%
europa = df[['Baltische Länder', 'Belgien',
       'Bulgarien', 'Dänemark', 'Deutschland', 'Finnland', 'Frankreich',
       'Griechenland', 'Irland', 'Italien', 'Kroatien', 'Luxemburg',
       'Niederlande', 'Norwegen', 'Österreich', 'Polen', 'Portugal',
       'Rumänien', 'Russische Föderation', 'Schweden', 'Slowakei', 'Spanien',
       'Tschechische Republik', 'Türkei', 'Ukraine', 'Ungarn',
       'Vereinigtes Königreich', 'Offshore-Finanzzentren Europa', 'EU',
       'Übriges Europa']]

europa.apply(lambda x: x/1000).head(5)
# Out:
#        Baltische Länder  Belgien  Bulgarien  Dänemark  Deutschland  Finnland  \
# Jahre
# 1998             0.0491   0.3487     0.0120   -0.0314       0.8885    0.2235
# 1999             0.0022   1.1785     0.0063    0.2801       5.7992    0.1264
# 2000             0.0208   4.4289    -0.0209   -0.1669      -1.1128    0.2632
# 2001            -0.0043  -0.5453     0.0022   -0.0290       5.6961    0.0986
# 2002             0.0785   2.0355     0.0013    0.0690       0.2472   -0.0076
#
#        Frankreich  Griechenland  Irland  Italien       ...        Slowakei  \
# Jahre                                                  ...
# 1998       0.3328        0.2050 -0.0536  -0.1970       ...          0.0210
# 1999       0.8267        0.1791  5.4459   0.1915       ...          0.0384
# 2000      -0.9327        0.3551  1.3032  -0.2217       ...          0.0129
# 2001      -1.5817        0.1673 -4.7130   1.9578       ...          0.0090
# ...

# %%
# farben_highlight = [{
#     'Belgien': '#FF5733',
#     'Bulgarien': '#FF5733',
#     'Irland': '#FF5733',
#     'Polen': '#FF5733',
#     'Slowakei': '#FF5733',
#     'Spanien': '#FF5733'}]


fig_eu = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Baltische Länder', 'Belgien',
       'Bulgarien', 'Dänemark', 'Deutschland', 'Finnland', 'Frankreich',
       'Griechenland', 'Irland', 'Italien', 'Kroatien', 'Luxemburg',
       'Niederlande', 'Norwegen', 'Österreich', 'Polen', 'Portugal',
       'Rumänien', 'Russische Föderation', 'Schweden', 'Slowakei', 'Spanien',
       'Tschechische Republik', 'Türkei', 'Ukraine', 'Ungarn',
       'Vereinigtes Königreich', 'Offshore-Finanzzentren Europa', #'EU',
       #'Übriges Europa'
      ], 
    #         color='farben_highlight',
    figsize=(25,15),
    grid=True,
    fontsize=24,
    title='Direktinvestitionen Europa',
    legend=False)
    
fig_eu.set_title('Direktinvestitionen Europa', fontname="Verdana", fontsize=40, pad=30)
    
fig_eu.legend(loc='center left', bbox_to_anchor=(1.0, 0.4), fontsize=24)
    
fig_eu.set_ylabel("Milliarden Franken", fontsize=24)
fig_eu.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig_eu.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig_eu.set_axisbelow(True)
    
# - Hintergrundfarbe
fig_eu.set_facecolor('#F4F9FB')
    
#fig.margins(y=0)

# - Rahmenlinien
# fig.spines['right'].set_visible(True)
# fig.spines['left'].set_visible(True)
# fig.spines['top'].set_visible(True)
# fig.spines['bottom'].set_visible(True)

# %%
# fig, ax =plt.subplots(1,2)
# sns.countplot(df['fig_eu'], ax=ax[0])
# sns.countplot(df['bowling'], ax=ax[1])
# fig.show()

# %% [markdown]
# ## Nordamerika

# %%
nordamerika = df[['Kanada', 'Vereinigte Staaten']]
nordamerika.apply(lambda x: x/1000).head(5)
# Out:
#        Kanada  Vereinigte Staaten
# Jahre
# 1998   1.2318              3.2262
# 1999   0.0833             13.5571
# 2000   0.5532             33.6783
# 2001   0.1083              9.5707
# 2002   0.3068              3.3356

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Kanada', 'Vereinigte Staaten'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Nordamerika',
    legend=False)
    
fig.set_title('Direktinvestitionen: Nordamerika', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %% [markdown]
# ## Mittel- und Südamerika

# %%
mittel_und_südamerika = df[['Argentinien', 'Bolivien', 'Brasilien', 'Chile', 'Costa Rica',
       'Ecuador', 'Guatemala', 'Kolumbien', 'Mexiko', 'Peru', 'Uruguay',
       'Venezuela', 'Offshore-Finanzzentren Mittel- und Südamerika']]

mittel_und_südamerika.apply(lambda x: x/1000).head(5)
# Out:
#        Argentinien  Bolivien  Brasilien   Chile  Costa Rica  Ecuador  \
# Jahre
# 1998        0.3214   -0.0031     0.4455 -0.1779     -0.0262   0.0100
# 1999       -0.1026   -0.0020     0.8444  0.0170     -0.0004   0.0195
# 2000        0.0475   -0.0002     0.2461 -0.0267     -0.0169   0.0234
# 2001        0.5334    0.0055    -0.8081 -0.1625      0.0132   0.0551
# 2002       -0.5416    0.0083    -0.6147 -0.0082      0.0168   0.0424
#
#        Guatemala  Kolumbien  Mexiko    Peru  Uruguay  Venezuela  \
# Jahre
# 1998     -0.0038     0.3871  0.6540 -0.0248   0.2835     0.0605
# 1999      0.0220     0.1153  0.5365  0.0466   0.2914     0.0110
# 2000     -0.0968    -0.1087  0.9100  0.0574   0.2988     0.1271
# 2001     -0.0084    -0.0700  0.9405  0.0355   0.0895     0.1757
# 2002     -0.0075    -0.2142  0.1835 -0.0418   0.1516    -0.2391
#
#        Offshore-Finanzzentren Mittel- und Südamerika
# Jahre
# 1998                                          2.9909
# ...

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Argentinien', 'Bolivien', 'Brasilien', 'Chile', 'Costa Rica',
       'Ecuador', 'Guatemala', 'Kolumbien', 'Mexiko', 'Peru', 'Uruguay',
       'Venezuela', 'Offshore-Finanzzentren Mittel- und Südamerika'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Nordamerika',
    legend=False)
    
fig.set_title('Direktinvestitionen: Mittel- und Südamerika', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(0, -0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Argentinien', 'Bolivien', 'Brasilien', 'Chile', 'Costa Rica',
       'Ecuador', 'Guatemala', 'Kolumbien', 'Mexiko', 'Peru', 'Uruguay',
       'Venezuela', #'Offshore-Finanzzentren Mittel- und Südamerika'
      ], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Nordamerika',
    legend=False)
    
fig.set_title('Direktinvestitionen: Mittel- und Südamerika, ohne Offshore', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %% [markdown]
# ## Asien

# %%
asien = df[['Bangladesch', 'China', 'Hongkong', 'Indien', 'Indonesien', 'Israel',
       'Japan', 'Korea Republik Süd-', 'Malaysia', 'Pakistan', 'Philippinen',
       'Saudi-Arabien', 'Singapur', 'Sri Lanka', 'Taiwan', 'Thailand',
       'Vereinigte Arabische Emirate', 'Vietnam']]
asien.apply(lambda x: x/1000).head(5)
# Out:
#        Bangladesch   China  Hongkong  Indien  Indonesien  Israel   Japan  \
# Jahre
# 1998        0.0338  0.1227    0.4466  0.0292      0.0895  0.0513  0.1235
# 1999        0.0054 -0.1427    0.6652 -0.0593      0.0101  0.0258  0.6276
# 2000        0.0020  0.2115   -0.0633 -0.0429     -0.0220  0.1890  0.3355
# 2001        0.0058  0.1805    0.0045  0.1392      0.1558  0.0450  0.7406
# 2002        0.0002 -0.0635   -0.3625  0.0755      0.0365 -0.0231 -0.4807
#
#        Korea Republik Süd-  Malaysia  Pakistan  Philippinen  Saudi-Arabien  \
# Jahre
# 1998                0.2826    0.1022   -0.0168       1.1685        -0.0020
# 1999                0.1792    0.2271    0.0067       0.0568         0.0596
# 2000                0.1840   -0.0251    0.0587       0.3129        -0.0833
# 2001                0.1616    0.0670    0.0421       0.0981        -0.0064
# 2002                0.0260   -0.0337    0.0182      -0.2720         0.0071
#
# ...

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Bangladesch', 'China', 'Hongkong', 'Indien', 'Indonesien', 'Israel',
       'Japan', 'Korea Republik Süd-', 'Malaysia', 'Pakistan', 'Philippinen',
       'Saudi-Arabien', 'Singapur', 'Sri Lanka', 'Taiwan', 'Thailand',
       'Vereinigte Arabische Emirate', 'Vietnam'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Nordamerika',
    legend=False)
    
fig.set_title('Direktinvestitionen: Asien', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %% [markdown]
# ## Afrika

# %%
afrika = df[['Ägypten','Côte dIvoire', 'Kenia', 'Marokko', 'Nigeria', 'Südafrika', 'Tunesien']]
afrika.apply(lambda x: x/1000).head(5)
# Out:
#        Ägypten  Côte dIvoire   Kenia  Marokko  Nigeria  Südafrika  Tunesien
# Jahre
# 1998    0.0569        0.0511 -0.0082  -0.0115   0.0051     0.1382    0.0000
# 1999    0.0931       -0.0260 -0.0051   0.0024  -0.0065     0.1155    0.0017
# 2000    0.0107       -0.0465  0.0093  -0.0296   0.0036     0.0175    0.0167
# 2001    0.0821       -0.0060  0.0044   0.0366   0.0084     0.0540    0.0045
# 2002    0.0476       -0.0929 -0.0007   0.0260   0.0007    -0.2377   -0.0102

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Ägypten','Côte dIvoire', 'Kenia', 'Marokko', 'Nigeria', 'Südafrika', 'Tunesien'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Afrika',
    legend=False)
    
fig.set_title('Direktinvestitionen: Afrika', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %% [markdown]
# ## Ozeanien

# %%
ozeanien = df[['Australien', 'Neuseeland']]
ozeanien.apply(lambda x: x/1000).head(5)
# Out:
#        Australien  Neuseeland
# Jahre
# 1998       0.5723      0.0111
# 1999       0.3222     -0.2153
# 2000      -0.2674     -0.0027
# 2001      -0.0664      0.0217
# 2002       0.4367     -0.0073

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Australien', 'Neuseeland'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Ozeanien',
    legend=False)
    
fig.set_title('Direktinvestitionen: Ozeanien', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %% [markdown]
# ## Alle Kontinente

# %%
df_eu = pd.read_excel('snb-data-fdiaustlanda-de-all-20171215_0900.xlsx')

df_eu = df_eu.set_index('Jahre')
df_eu.fillna(0)

df_eu.columns = df_eu.columns.str.strip().str.replace(
    'Alle Länder - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df_eu.columns = df_eu.columns.str.strip('_')
fig = df_eu.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Europa - Total',
       'Nordamerika - Total',
       'Mittel- und Südamerika - Total',
       'Asien - Total',
       'Afrika - Total',
       'Ozeanien - Total'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen Länder: Total Kontinente',
    legend=False)
    
fig.set_title('Direktinvestitionen Länder: Total Kontinente', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
df = pd.read_excel('snb-data-fdiaustlanda-de-all-20171215_0900.xlsx')

df = df.set_index('Jahre')
df.fillna(0)

df.columns = df.columns.str.strip().str.replace(
    'Alle Länder - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df.columns = df.columns.str.strip('_')

fig = df.iloc[8:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Europa - Total',
       'Nordamerika - Total',
       'Mittel- und Südamerika - Total',
       'Asien - Total',
       'Afrika - Total',
       'Ozeanien - Total'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    legend=False)
    
fig.set_title('Direktinvestitionen Länder: Total Kontinente – 2006 bis 2016', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
df_kon = pd.read_excel('snb-data-fdiaustlanda-de-all-20171215_0900.xlsx')

df_kon = df_kon.set_index('Jahre')
df_kon.fillna(0)

df_kon.columns = df.columns.str.strip().str.replace(
    'Alle Länder - ', '_').str.replace(
    '(', '').str.replace('', '').str.replace("'", "")

df_kon.columns = df.columns.str.strip('_')

fig = df_kon.iloc[16:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Europa - Total',
       'Nordamerika - Total',
       'Mittel- und Südamerika - Total',
       'Asien - Total',
       'Afrika - Total',
       'Ozeanien - Total'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    legend=False)
    
fig.set_title('Direktinvestitionen Länder: Total Kontinente – ab 2014', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')

# %%
# df_kon.plot(<X AXIS VALUES HERE>, <Y AXIS VALUES HERE>, 'line type', label='label here')
# df_eu.plot(<X AXIS VALUES HERE>, <Y AXIS VALUES HERE>, 'line type', label='label here')
# plt.legend(loc='best')
# plt.show()

# %%
# ax = df_kon.plot(kind='bar')
# df_eu.plot(ax=ax)

# %%
# fig, axes = plt.subplots(nrows=2, ncols=2)

# df_kon.plot(ax=axes[0,0], kind='bar', figsize=(25,15))
# df_eu.plot(ax=axes[1,0])

# %%
# fig, ax = plt.subplots(figsize=(15,7))
# data.groupby(['date','type']).count()['amount'].unstack().plot(ax=ax)
# ax.set_xlabel('Date')
# ax.set_ylabel('Number of transactions')
