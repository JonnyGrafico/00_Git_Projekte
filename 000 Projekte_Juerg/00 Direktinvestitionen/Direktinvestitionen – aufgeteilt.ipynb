# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('00_snb-data_bearbeitet.xlsx', index_col=0, header=15)
# df = pd.read_excel('00_snb-data_bearbeitet.xlsx')

# %%
# df1 = df1.fillna('XX')

df.head(5)
# Out:
#            Beteiligungskapital ohne reinvestierte Erträge  \
# Kapitalart
# Jahre alle                              Industrie - Total
# 1998                                                 6374
# 1999                                                 4606
# 2000                                              17634.5
# 2001                                               8012.8
#
#            Beteiligungskapital ohne reinvestierte Erträge.1  \
# Kapitalart
# Jahre alle             Industrie - Textilien und Bekleidung
# 1998                                                  285.5
# 1999                                                    440
# 2000                                                     19
# 2001                                                 -224.9
#
#            Beteiligungskapital ohne reinvestierte Erträge.2  \
# Kapitalart
# Jahre alle               Industrie - Chemie und Kunststoffe
# 1998                                                 3829.8
# 1999                                                  198.5
# 2000                                                 7680.3
# 2001                                                 2583.7
#
#            Beteiligungskapital ohne reinvestierte Erträge.3  \
# Kapitalart
# Jahre alle                Industrie - Metalle und Maschinen
# 1998                                                  819.5
# 1999                                                  650.8
# 2000                                                 1271.6
# 2001                                                 1707.4
#
#             Beteiligungskapital ohne reinvestierte Erträge.4  \
# Kapitalart
# Jahre alle  Industrie - Elektronik, Energie, Optik und Uhren
# 1998                                                     108
# 1999                                                  1111.1
# 2000                                                    2062
# 2001                                                  2071.5
#
#            Beteiligungskapital ohne reinvestierte Erträge.5  \
# Kapitalart
# Jahre alle            Industrie - Übrige Industrien und Bau
# 1998                                                 1331.2
# 1999                                                 2205.6
# 2000                                                 6601.6
# 2001                                                 1875.1
#
#            Beteiligungskapital ohne reinvestierte Erträge.6  \
# Kapitalart
# Jahre alle                                  Dienste - Total
# 1998                                                10574.8
# 1999                                                19229.1
# 2000                                                38377.8
# 2001                                                13982.6
#
#            Beteiligungskapital ohne reinvestierte Erträge.7  \
# Kapitalart
# Jahre alle                                 Dienste - Handel
# 1998                                                    369
# 1999                                                   52.8
# 2000                                                  109.2
# 2001                                                  890.9
#
#              Beteiligungskapital ohne reinvestierte Erträge.8  \
# Kapitalart
# Jahre alle  Dienste - Finanz- und Holdinggesellschaften - ...
# 1998                                                    565.5
# 1999                                                   3778.3
# 2000                                                   1900.7
# 2001                                                    167.5
#
#              Beteiligungskapital ohne reinvestierte Erträge.9  \
# Kapitalart
# Jahre alle  Dienste - Finanz- und Holdinggesellschaften - ...
# 1998                                                   1133.4
# 1999                                                    150.3
# 2000                                                   2002.9
# 2001                                                   1394.8
#
#                                   ...                          \
# Kapitalart                        ...
# Jahre alle                        ...
# 1998                              ...
# 1999                              ...
# 2000                              ...
# 2001                              ...
#
#                                                      Total.10  \
# Kapitalart
# Jahre alle  Dienste - Finanz- und Holdinggesellschaften - ...
# 1998                                                   3869.9
# 1999                                                  11479.6
# 2000                                                    257.6
# 2001                                                   1884.7
#
#                                                      Total.11  \
# Kapitalart
# Jahre alle  Dienste - Finanz- und Holdinggesellschaften - ...
# 1998                                                      NaN
# 1999                                                      NaN
# 2000                                                      NaN
# 2001                                                      NaN
#
#                     Total.12                  Total.13  \
# Kapitalart
# Jahre alle  Dienste - Banken  Dienste - Versicherungen
# 1998                  -321.2                    8034.4
# 1999                    6082                    9910.2
# 2000                 31059.1                   14041.6
# 2001                  -793.6                    7492.8
#
#                                           Total.14                  Total.15  \
# Kapitalart
# Jahre alle  Dienste - Transporte und Kommunikation  Dienste - Übrige Dienste
# 1998                                         859.3                        62
# 1999                                        3524.3                    4121.3
# 2000                                         196.3                    2265.6
# 2001                                        1521.1                      1528
#
#            Total.16                                           Total.17  \
# Kapitalart
# Jahre alle    Total  Total ohne ausländisch beherrschte Finanz- und...
# 1998        27209.2                                            23339.3
# 1999        49986.2                                            38506.6
# 2000        75445.8                                            75188.2
# 2001        30916.2                                            29031.5
#
#                                                Total.18  \
# Kapitalart
# Jahre alle  Pro memoria: Grundstücks- und Wohnungswesen
# 1998                                                NaN
# 1999                                                NaN
# 2000                                                NaN
# 2001                                                NaN
#
#                                                      Total.19
# Kapitalart
# Jahre alle  Pro memoria: Total inkl. Grundstücks- und Wohn...
# 1998                                                  27209.2
# 1999                                                  49986.2
# 2000                                                  75445.6
# 2001                                                  30916.2
#
# [5 rows x 76 columns]

# %%
df = df[['Beteiligungskapital ohne reinvestierte Erträge']]
df.head()
# Out:
#            Beteiligungskapital ohne reinvestierte Erträge
# Kapitalart
# Jahre alle                              Industrie - Total
# 1998                                                 6374
# 1999                                                 4606
# 2000                                              17634.5
# 2001                                               8012.8

# %%
new_header = df.iloc[0] #grab the first row for the header
df1 = df[1:] #take the data less the header row
df1.columns = new_header #set the header row as the df header
df1.head(20)
# Out:
# Jahre alle Industrie - Total
# Kapitalart
# 1998                    6374
# 1999                    4606
# 2000                 17634.5
# 2001                  8012.8
# 2002                 11437.2
# 2003                  2180.9
# 2004                 11829.5
# 2005                 10192.9
# 2006                 30913.1
# 2007                  9862.1
# 2008                 14370.8
# 2009                     8.2
# 2010                  1400.5
# 2011                 -8520.4
# 2012                  9014.2
# 2013                 -3108.7
# 2014                -6511.98
# 2015                 1856.29
# 2016                 20677.6

# %%
df1.columns
# Out:
# Index(['Industrie - Total'], dtype='object', name='Jahre alle')

# %%
new_header = df1.iloc[0] #grab the first row for the header
df1 = df1[1:] #take the data less the header row
df1.columns = new_header #set the header row as the df header
df1.head()
# Out:
# 1998           6374
# Kapitalart
# 1999           4606
# 2000        17634.5
# 2001         8012.8
# 2002        11437.2
# 2003         2180.9

# %%
df1.drop(['NaN']).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8bc24937e4bb> in <module>
# ----> 1 df1.drop(['NaN']).head()
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['NaN'] not found in axis"

# %%
df1.columns

# %%
# df.plot(kind='scatter', 
#         x='gdp_per_capita', 
#         y='life_expectancy',
#         figsize=(10,7))

# %%
# iloc[17:23, 10:21].apply(lambda x: x/1000).

# %%
# df1 = df1.set_index(['Jahre alle'])
# df1.head(5)

# %%
# df1.drop(['XX']).head()

# %%
df1.columns
# Out:
# Int64Index([6374], dtype='int64', name='1998')

# %%
df1.plot(kind='bar',x='Jahre alle',y='Industrie - Chemie und Kunststoffe')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Jahre alle'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-4c4515f36759> in <module>
# ----> 1 df1.plot(kind='bar',x='Jahre alle',y='Industrie - Chemie und Kunststoffe')
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1764                 if is_integer(x) and not data.columns.holds_integer():
#    1765                     x = data_cols[x]
# -> 1766                 elif not isinstance(data[x], ABCSeries):
#    1767                     raise ValueError("x must be a label or position")
#    1768                 data = data.set_index(x)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Jahre alle'

# %%
# fig.set_title('Direktinvestitionen: Dienste – Holdings', fontname="Verdana", fontsize=30, pad=30)
# fig.legend(loc='center left', bbox_to_anchor=(0, -0.3), fontsize=20)
    
# fig.set_ylabel("Milliarden Franken", fontsize=24)
# fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
# fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
# fig.set_axisbelow(True)
    
# fig.set_facecolor('#F4F9FB')

# %%
df2 = pd.read_excel('00_snb-data_reduziert.xlsx', index_col=0, header=0)
#df = pd.read_excel('00_snb-data_reduziert.xlsx')

# %%
df2 = df1.fillna('XX')
df2.head(20)
# Out:
# Kapitalart                                   Beteiligungskapital ohne reinvestierte Erträge  \
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                                                Industrie - Total
# NaN                                                            EPB@SNB.fdiaustabsa{D0_0,T0}
# 1998                                                                                   6374
# 1999                                                                                   4606
# 2000                                                                                17634.5
# 2001                                                                                 8012.8
# 2002                                                                                11437.2
# 2003                                                                                 2180.9
# 2004                                                                                11829.5
# 2005                                                                                10192.9
# 2006                                                                                30913.1
# 2007                                                                                 9862.1
# 2008                                                                                14370.8
# 2009                                                                                    8.2
# 2010                                                                                 1400.5
# 2011                                                                                -8520.4
# 2012                                                                                 9014.2
# 2013                                                                                -3108.7
# 2014                                                                               -6511.98
# 2015                                                                                1856.29
#
# Kapitalart                                   Beteiligungskapital ohne reinvestierte Erträge  \
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                             Industrie - Textilien und Bekleidung
# NaN                                                           EPB@SNB.fdiaustabsa{D0_0,TUB}
# 1998                                                                                  285.5
# 1999                                                                                    440
# 2000                                                                                     19
# 2001                                                                                 -224.9
# 2002                                                                                   37.3
# 2003                                                                                  421.5
# 2004                                                                                  791.4
# 2005                                                                                 1430.3
# 2006                                                                                 1838.7
# 2007                                                                                   3592
# 2008                                                                                   1034
# 2009                                                                                    -69
# 2010                                                                                -3157.4
# 2011                                                                                -4491.2
# 2012                                                                                 1073.2
# 2013                                                                                 -968.3
# 2014                                                                                 -541.7
# 2015                                                                                 -454.9
#
# Kapitalart                                   Beteiligungskapital ohne reinvestierte Erträge  \
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                               Industrie - Chemie und Kunststoffe
# NaN                                                           EPB@SNB.fdiaustabsa{D0_0,CUK}
# 1998                                                                                 3829.8
# 1999                                                                                  198.5
# 2000                                                                                 7680.3
# 2001                                                                                 2583.7
# 2002                                                                                   3444
# 2003                                                                                 -225.3
# 2004                                                                                 7521.2
# 2005                                                                                 6763.7
# 2006                                                                                 9533.2
# 2007                                                                                  165.1
# 2008                                                                                 5693.1
# 2009                                                                                  -3851
# 2010                                                                                 4462.7
# 2011                                                                                -4833.6
# 2012                                                                                 2199.3
# 2013                                                                                -1846.1
# 2014                                                                               -151.989
# 2015                                                                                3072.03
#
# Kapitalart                                   Beteiligungskapital ohne reinvestierte Erträge  \
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                                Industrie - Metalle und Maschinen
# NaN                                                           EPB@SNB.fdiaustabsa{D0_0,MUM}
# 1998                                                                                  819.5
# 1999                                                                                  650.8
# 2000                                                                                 1271.6
# 2001                                                                                 1707.4
# 2002                                                                                  431.8
# 2003                                                                                 1327.8
# 2004                                                                                 2249.5
# 2005                                                                                 -585.9
# 2006                                                                                 7321.6
# 2007                                                                                   3751
# 2008                                                                                  698.2
# 2009                                                                                   1162
# 2010                                                                                -1089.3
# 2011                                                                                -7439.4
# 2012                                                                                 1274.3
# 2013                                                                                 -782.2
# 2014                                                                                1252.58
# 2015                                                                               -1717.27
#
# Kapitalart                                      Beteiligungskapital ohne reinvestierte Erträge  \
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                    
total  \
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                    Total ohne ausländisch beherrschte Finanz- und...
# NaN                                                              EPB@SNB.fdiaustabsa{D0_3,D1_3}
# 1998                                                                                    23339.3
# 1999                                                                                    38506.6
# 2000                                                                                    75188.2
# 2001                                                                                    29031.5
# 2002                                                                                     8249.4
# 2003                                                                                    16098.3
# 2004                                                                                    30420.5
# 2005                                                                                    55200.6
# 2006                                                                                    89700.3
# 2007                                                                                    50122.3
# 2008                                                                                    43311.6
# 2009                                                                                    27576.1
# 2010                                                                                      41286
# 2011                                                                                    43970.2
# 2012                                                                                    48120.4
# 2013                                                                                      38521
# 2014                                                                                   -10433.5
# 2015                                                                                    50994.7
#
# Kapitalart                                                                          Total  \
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                    Pro memoria: Grundstücks- und Wohnungswesen
# NaN                                                         EPB@SNB.fdiaustabsa{D0_3,PMG}
# 1998                                                                                   XX
# 1999                                                                                   XX
# 2000                                                                                   XX
# 2001                                                                                   XX
# 2002                                                                                   XX
# 2003                                                                                    0
# 2004                                                                                    0
# 2005                                                                                    0
# 2006                                                                              852.446
# 2007                                                                              694.784
# 2008                                                                             -513.841
# 2009                                                                             -148.883
# 2010                                                                              502.495
# 2011                                                                              358.635
# 2012                                                                              459.623
# 2013                                                                             -30.4529
# 2014                                                                              215.882
# 2015                                                                               280.15
#
# Kapitalart                                                                                Total
# Datenportal der Schweizerischen Nationalbank
# Jahre alle                                    Pro memoria: Total inkl. Grundstücks- und Wohn...
# NaN                                                               EPB@SNB.fdiaustabsa{D0_3,PMT}
# 1998                                                                                    27209.2
# 1999                                                                                    49986.2
# 2000                                                                                    75445.6
# 2001                                                                                    30916.2
# 2002                                                                                    12785.2
# 2003                                                                                    20794.8
# 2004                                                                                    32665.8
# 2005                                                                                    63650.6
# 2006                                                                                    95923.4
# 2007                                                                                    61937.1
# 2008                                                                                    48586.1
# 2009                                                                                    28554.4
# 2010                                                                                    89880.6
# 2011                                                                                    43113.2
# 2012                                                                                    41329.9
# 2013                                                                                    35721.9
# 2014                                                                                    50.5284
# 2015                                                                                    90358.1
#
# [20 rows x 76 columns]

# %%
df2.columns
# Out:
# Index(['Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Beteiligungskapital ohne reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Reinvestierte Erträge', 'Reinvestierte Erträge',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel',
#        'Kredite und Schuldtitel', 'Kredite und Schuldtitel', 'Total', 'Total',
#        'Total', 'Total', 'Total', 'Total', 'Total', 'Total', 'Total', 'Total',
#        'Total', 'Total', 'Total', 'Total', 'Total', 'Total', 'Total', 'Total',
#        'Total', 'Total'],
#       dtype='object', name='Kapitalart')

# %%
# df2.plot(kind='bar',x='Jahre',y='Industrie - Chemie und Kunststoffe', 'Industrie - Metalle und Maschinen')

# %%
fig = df2.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Dienste - Handel',
       'Dienste - Finanz- und Holdinggesellschaften - Total',
       'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
       'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total.3',
       'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities.3'], 
    figsize=(25,15),
    grid=True,
    fontsize=22,
    title='Direktinvestitionen: Dienste – Holdings',
    legend=False)
    
fig.set_title('Direktinvestitionen: Dienste – Holdings', fontname="Verdana", fontsize=30, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(0, -0.3), fontsize=20)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1022                 mask = notna(x)
# -> 1023                 result[mask] = op(x[mask], y)
#    1024
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b8b0085b9d62> in <module>
# ----> 1 fig = df2.iloc[0:19].apply(lambda x: x/1000).plot(
#       2     kind='bar',
#       3 #     x='Jahre',
#       4     y=['Dienste - Handel',
#       5        'Dienste - Finanz- und Holdinggesellschaften - Total',
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-30-b8b0085b9d62> in <lambda>(x)
# ----> 1 fig = df2.iloc[0:19].apply(lambda x: x/1000).plot(
#       2     kind='bar',
#       3 #     x='Jahre',
#       4     y=['Dienste - Handel',
#       5        'Dienste - Finanz- und Holdinggesellschaften - Total',
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/ops.py in <lambda>(x)
#    1035             if is_object_dtype(lvalues):
#    1036                 return libalgos.arrmap_object(lvalues,
# -> 1037                                               lambda x: op(x, rvalues))
#    1038             raise
#    1039
#
# TypeError: ("unsupported operand type(s) for /: 'str' and 'int'", 'occurred at index Beteiligungskapital ohne reinvestierte Erträge')

# %%
# df.plot(kind='scatter', 
#         x='gdp_per_capita', 
#         y='life_expectancy',
#         figsize=(10,7))

# %%
# iloc[17:23, 10:21].apply(lambda x: x/1000).

# %%
# df1 = df1.set_index(['Jahre alle'])
# df1.head(5)

# %%
# df1.drop(['XX']).head()

# %%
df1.columns
# Out:
# Int64Index([6374], dtype='int64', name='1998')

# %%
df1.plot(kind='bar',x='Jahre alle',y='Industrie - Chemie und Kunststoffe')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Jahre alle'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-4c4515f36759> in <module>
# ----> 1 df1.plot(kind='bar',x='Jahre alle',y='Industrie - Chemie und Kunststoffe')
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1764                 if is_integer(x) and not data.columns.holds_integer():
#    1765                     x = data_cols[x]
# -> 1766                 elif not isinstance(data[x], ABCSeries):
#    1767                     raise ValueError("x must be a label or position")
#    1768                 data = data.set_index(x)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Jahre alle'

# %%
# fig.set_title('Direktinvestitionen: Dienste – Holdings', fontname="Verdana", fontsize=30, pad=30)
# fig.legend(loc='center left', bbox_to_anchor=(0, -0.3), fontsize=20)
    
# fig.set_ylabel("Milliarden Franken", fontsize=24)
# fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
# fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
# fig.set_axisbelow(True)
    
# fig.set_facecolor('#F4F9FB')

# %%
df1 = pd.read_excel('00_snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
# df = pd.read_excel('00_snb-data-fdiaustabsa-de-all-20171215_0900.xlsx')

df1 = df1.fillna('XX')
df1.head(20)

new_header = df1.iloc[15] #grab the first row for the header
df1 = df1[16:] #take the data less the header row
df1.columns = new_header #set the header row as the df header
df1.head()

df1 = df[['Kapitalart', 'Beteiligungskapital ohne reinvestierte Erträge']]
df1.head()

new_header = df1.iloc[0] #grab the first row for the header
df1 = df1[1:] #take the data less the header row
df1.columns = new_header #set the header row as the df header
df1.head()

df1.drop([17]).head()

df1.columns



# df.plot(kind='scatter', 
#         x='gdp_per_capita', 
#         y='life_expectancy',
#         figsize=(10,7))



# iloc[17:23, 10:21].apply(lambda x: x/1000).

# df1 = df1.set_index(['Jahre alle'])
# df1.head(5)

# df1.drop(['XX']).head()

df1.columns

df1.plot(kind='bar',x='Jahre alle',y='Industrie - Chemie und Kunststoffe')

# fig.set_title('Direktinvestitionen: Dienste – Holdings', fontname="Verdana", fontsize=30, pad=30)
# fig.legend(loc='center left', bbox_to_anchor=(0, -0.3), fontsize=20)
    
# fig.set_ylabel("Milliarden Franken", fontsize=24)
# fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
# fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
# fig.set_axisbelow(True)
    
# fig.set_facecolor('#F4F9FB')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-ddd38c11b40e> in <module>
#      10 df1.head()
#      11
# ---> 12 df1 = df[['Kapitalart', 'Beteiligungskapital ohne reinvestierte Erträge']]
#      13 df1.head()
#      14
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/.virtualenvs/masterEV/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['Kapitalart'] not in index"

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df = pd.read_excel('snb-data-fdiaustabsa-de-all-20171215_0900.xlsx', index_col=0, header=0)
df = pd.read_excel('00_snb-data_reduziert.xlsx')

# %%
df.head()
# Out:
#    Jahre  Industrie - Total  Industrie - Textilien und Bekleidung  \
# 0   1998             6374.0                                 285.5
# 1   1999             4606.0                                 440.0
# 2   2000            17634.5                                  19.0
# 3   2001             8012.8                                -224.9
# 4   2002            11437.2                                  37.3
#
#    Industrie - Chemie und Kunststoffe  Industrie - Metalle und Maschinen  \
# 0                              3829.8                              819.5
# 1                               198.5                              650.8
# 2                              7680.3                             1271.6
# 3                              2583.7                             1707.4
# 4                              3444.0                              431.8
#
#    Industrie - Elektronik, Energie, Optik und Uhren  \
# 0                                             108.0
# 1                                            1111.1
# 2                                            2062.0
# 3                                            2071.5
# 4                                             232.8
#
#    Industrie - Übrige Industrien und Bau  Dienste - Total  Dienste - Handel  \
# 0                                 1331.2          10574.8             369.0
# 1                                 2205.6          19229.1              52.8
# 2                                 6601.6          38377.8             109.2
# 3                                 1875.1          13982.6             890.9
# 4                                 7291.3          13146.4             -90.2
#
#    Dienste - Finanz- und Holdinggesellschaften - Total  \
# 0                                              565.5
# 1                                             3778.3
# 2                                             1900.7
# 3                                              167.5
# 4                                             3710.7
#
#                             ...                             \
# 0                           ...
# 1                           ...
# 2                           ...
# 3                           ...
# 4                           ...
#
#    Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total  \
# 0                                             -567.9
# 1                                             3628.0
# 2                                             -102.2
# 3                                            -1227.3
# 4                                             1365.5
#
#    Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Dienste - Banken  Dienste - Versicherungen  \
# 0            2869.2                    6227.4
# 1            3936.7                    5792.6
# 2           26993.4                    7181.5
# 3            1597.2                    7531.7
# 4            7931.0                    2100.5
#
#    Dienste - Transporte und Kommunikation  Dienste - Übrige Dienste    Total  \
# 0                                   742.4                    -198.7  16948.8
# 1                                  3581.5                    2087.2  23835.1
# 2                                  1224.5                     968.5  56012.3
# 3                                   863.3                    2932.0  21995.4
# 4                                    35.0                    -540.6  24583.6
#
#    Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften  \
# 0                                            17516.7
# 1                                            20207.1
# 2                                            56114.5
# 3                                            23222.7
# 4                                            23218.1
#
#    Pro memoria: Grundstücks- und Wohnungswesen  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Pro memoria: Total inkl. Grundstücks- und Wohnungswesen
# 0                                            16948.8
# 1                                            23835.1
# 2                                            56012.3
# 3                                            21995.4
# 4                                            24583.6
#
# [5 rows x 21 columns]

# %%
#df.tail()

# %%
df = df.set_index('Jahre')
df.fillna(0).head(5)
# Out:
#        Industrie - Total  Industrie - Textilien und Bekleidung  \
# Jahre
# 1998              6374.0                                 285.5
# 1999              4606.0                                 440.0
# 2000             17634.5                                  19.0
# 2001              8012.8                                -224.9
# 2002             11437.2                                  37.3
#
#        Industrie - Chemie und Kunststoffe  Industrie - Metalle und Maschinen  \
# Jahre
# 1998                               3829.8                              819.5
# 1999                                198.5                              650.8
# 2000                               7680.3                             1271.6
# 2001                               2583.7                             1707.4
# 2002                               3444.0                              431.8
#
#        Industrie - Elektronik, Energie, Optik und Uhren  \
# Jahre
# 1998                                              108.0
# 1999                                             1111.1
# 2000                                             2062.0
# 2001                                             2071.5
# 2002                                              232.8
#
#        Industrie - Übrige Industrien und Bau  Dienste - Total  \
# Jahre
# 1998                                  1331.2          10574.8
# 1999                                  2205.6          19229.1
# 2000                                  6601.6          38377.8
# 2001                                  1875.1          13982.6
# 2002                                  7291.3          13146.4
#
#        Dienste - Handel  Dienste - Finanz- und Holdinggesellschaften - Total  \
# Jahre
# 1998              369.0                                              565.5
# 1999               52.8                                             3778.3
# 2000              109.2                                             1900.7
# 2001              890.9                                              167.5
# 2002              -90.2                                             3710.7
#
#        Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht  \
# Jahre
# 1998                                              1133.4
# 1999                                               150.3
# 2000                                              2002.9
# 2001                                              1394.8
# 2002                                              2345.2
#
#        Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total  \
# Jahre
# 1998                                              -567.9
# 1999                                              3628.0
# 2000                                              -102.2
# 2001                                             -1227.3
# 2002                                              1365.5
#
#        Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities  \
# Jahre
# 1998                                                 0.0
# 1999                                                 0.0
# 2000                                                 0.0
# 2001                                                 0.0
# 2002                                                 0.0
#
#        Dienste - Banken  Dienste - Versicherungen  \
# Jahre
# 1998             2869.2                    6227.4
# 1999             3936.7                    5792.6
# 2000            26993.4                    7181.5
# 2001             1597.2                    7531.7
# 2002             7931.0                    2100.5
#
#        Dienste - Transporte und Kommunikation  Dienste - Übrige Dienste  \
# Jahre
# 1998                                    742.4                    -198.7
# 1999                                   3581.5                    2087.2
# 2000                                   1224.5                     968.5
# 2001                                    863.3                    2932.0
# 2002                                     35.0                    -540.6
#
#          Total  \
# Jahre
# 1998   16948.8
# 1999   23835.1
# 2000   56012.3
# 2001   21995.4
# 2002   24583.6
#
#        Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften  \
# Jahre
# 1998                                             17516.7
# 1999                                             20207.1
# 2000                                             56114.5
# 2001                                             23222.7
# 2002                                             23218.1
#
#        Pro memoria: Grundstücks- und Wohnungswesen  \
# Jahre
# 1998                                           0.0
# 1999                                           0.0
# 2000                                           0.0
# 2001                                           0.0
# 2002                                           0.0
#
#        Pro memoria: Total inkl. Grundstücks- und Wohnungswesen
# Jahre
# 1998                                             16948.8
# 1999                                             23835.1
# 2000                                             56012.3
# 2001                                             21995.4
# 2002                                             24583.6

# %%
df.columns
# Out:
# Index(['Industrie - Total', 'Industrie - Textilien und Bekleidung',
#        'Industrie - Chemie und Kunststoffe',
#        'Industrie - Metalle und Maschinen',
#        'Industrie - Elektronik, Energie, Optik und Uhren',
#        'Industrie - Übrige Industrien und Bau', 'Dienste - Total',
#        'Dienste - Handel',
#        'Dienste - Finanz- und Holdinggesellschaften - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total',
#        'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities',
#        'Dienste - Banken', 'Dienste - Versicherungen',
#        'Dienste - Transporte und Kommunikation', 'Dienste - Übrige Dienste',
#        'Total',
#        'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#        'Pro memoria: Grundstücks- und Wohnungswesen',
#        'Pro memoria: Total inkl. Grundstücks- und Wohnungswesen'],
#       dtype='object')

# %%
# df.columns = df.columns.str.strip().str.replace(
#     'Industrie - ', '_').str.replace(
#     'Dienste - ', '_').str.replace(
#     'Dienste - Finanz- und Holdinggesellschaften - ', '_').str.replace(
#     'Alle Länder - Asien - ', '_').str.replace(
#     '(', '').str.replace('', '').str.replace("'", "")

# df.columns = df.columns.str.strip('_').str.strip(')')

# %%
#df.columns

# %%
industrie_dienste = df[['Industrie - Total','Dienste - Total']]
industrie_dienste.apply(lambda x: x/1000).head(5)
# Out:
#        Industrie - Total  Dienste - Total
# Jahre
# 1998              6.3740          10.5748
# 1999              4.6060          19.2291
# 2000             17.6345          38.3778
# 2001              8.0128          13.9826
# 2002             11.4372          13.1464

# %%
fig = df.iloc[0:19].apply(lambda x: x/1000).plot(
    kind='bar',
#     x='Jahre',
    y=['Industrie - Total','Dienste - Total'], 
    figsize=(25,15),
    grid=True,
    fontsize=25,
    title='Direktinvestitionen: Industrie und Dienste',
    legend=False)
    
fig.set_title('Direktinvestitionen: Industrie und Dienste', fontname="Verdana", fontsize=40, pad=30)
fig.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), fontsize=24)
    
fig.set_ylabel("Milliarden Franken", fontsize=24)
fig.set_xlabel("Jahre", fontname="Arial", fontsize=24, fontweight='bold')
    
fig.grid(b=None, which='major', axis='both', color='#D4D9DB', linestyle='dotted', linewidth=2)
fig.set_axisbelow(True)
    
fig.set_facecolor('#F4F9FB')
