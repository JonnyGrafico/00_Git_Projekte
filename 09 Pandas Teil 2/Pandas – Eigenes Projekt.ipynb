# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
df = pd.read_excel('dataprojects/2_4_KONTINENTE_EXPIMP.xlsx')

# %%
df.dtypes
# Out:
# Aussenhandel der Schweiz nach Kontinenten, 2013-2017     object
# Unnamed: 1                                               object
# Unnamed: 2                                               object
# Unnamed: 3                                              float64
# Unnamed: 4                                              float64
# Unnamed: 5                                              float64
# Unnamed: 6                                              float64
# Unnamed: 7                                               object
# Unnamed: 8                                              float64
# Unnamed: 9                                              float64
# Unnamed: 10                                             float64
# Unnamed: 11                                             float64
# dtype: object

# %%
df.transpose()
# Out:
#                                                                            0   \
# Aussenhandel der Schweiz nach Kontinenten, 2013...  Wert in Millionen Franken
# Unnamed: 1                                                                NaN
# Unnamed: 2                                                                NaN
# Unnamed: 3                                                                NaN
# Unnamed: 4                                                                NaN
# Unnamed: 5                                                                NaN
# Unnamed: 6                                                                NaN
# Unnamed: 7                                                                NaN
# Unnamed: 8                                                                NaN
# Unnamed: 9                                                                NaN
# Unnamed: 10                                                               NaN
# ...
